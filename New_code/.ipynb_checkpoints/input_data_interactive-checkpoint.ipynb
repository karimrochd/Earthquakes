# %%
from importlib import reload

import h5py
import numpy as np
import sys
import utilities

reload(utilities)
# Out:
# <module 'utilities' from "/Users/gloirelinvani/Library/Mobile Documents/com~apple~CloudDocs/School/Magistère d'Informatique/LDD3/S6/Stage/Earthquakes/earthquakes/New_code/utilities.py">

# %% [markdown]
# # Parameters

# %%
hdf5_in_put_file_path = "Data/Data_min_mainshock_mag=6_min_stations_per_main_shock=3_min_after_shock_mag=5_after_shock_time_window=45_n_days_before_mainshock=7_n_days_after_mainshock=7.hdf5"  #Path to the HDF5 output file
hdf5_out_put_file_path = "Data/Interpolated_Data_and_labels_min_mainshock_mag=6_min_stations_per_main_shock=3_min_after_shock_mag=5_after_shock_time_window=45_n_days_before_mainshock=7_n_days_after_mainshock=7.hdf5"  #Path to the HDF5 output file
earth_radius = 6371  # km
grid_size_km = 250  # Size of the grid in km
cell_size_km = 5  #Cell size in km
cell_size_rads = cell_size_km / earth_radius
cell_size_degs = cell_size_rads * 180 / np.pi
scale_factor = 1e6  # Scale factor for the coordinates from km to mm
num_cells = int(grid_size_km / cell_size_km)  # number of cells in the lateral direction
min_stations_inside = 3  # minimal number of stations inside the grid
soft_labels = False  ## smoothed labels (from {0,1} to continuous, smoothed over space)
sigma_softlabels = 1  # sigma for the gaussian smoothing of the labels, expressed in number of cell sizes
sigma_interpolation = 8  ## expressed in number of cell sizes

# %% [markdown]
# # Functions to build displacement maps and labels for each main shock in input HDF5 file

# %%
## Global variables:
n_seq_init = 0  # Number of sequences processed
n_seq_discarded = 0  # Number of sequences discarded


def process_main_shock_data(hdf5_file_path, output_path):
    """Process main shocks data to generate interpolated displacement maps."""
    with h5py.File(hdf5_file_path, 'r') as file:
        for id_seq in file.keys():
            process_single_main_shock(file[id_seq], output_path, id_seq)
            ## file[id_seq] == grp
        


def calculate_interpolation_grid(main_shock_location, cell_size_degs, num_cells_half):
    min_lat = main_shock_location[0] - num_cells_half * cell_size_degs
    max_lat = main_shock_location[0] + num_cells_half * cell_size_degs
    min_lon = main_shock_location[1] - num_cells_half * cell_size_degs
    max_lon = main_shock_location[1] + num_cells_half * cell_size_degs
    n_pixels_lat = 2 * num_cells_half  # Number of discretizations in the latitude direction
    n_pixels_lon = n_pixels_lat  # Number of discretizations in the longitude direction (cells)
    return min_lat, max_lat, min_lon, max_lon, n_pixels_lat, n_pixels_lon


def process_single_main_shock(main_shock_group, output_path, id_seq):
    global n_seq_init, n_seq_discarded
    n_seq_init += 1
    print(f"Processing main shock {id_seq}...")
    gps_stations_displacements = main_shock_group['gps_stations_displacements'][()]
    # For each station, multiply the displacement by the scale factor and sum the displacements
    # over the time dimension
    ## gps_stations_displacements: (NbStations, NbDays, Displacement(X,Y,Z))
    gps_stations_displacements = (gps_stations_displacements * scale_factor) ## conevrt to mm
    gps_stations_displacements = (gps_stations_displacements).sum(axis=1)   # sum over days (gets rid of 0's)
    gps_stations_displacements = gps_stations_displacements.reshape(-1, 3)  ## (NbStations, (X,Y,Z))
    stations_positions = main_shock_group['stations_positions'][()]
    main_shock_location = main_shock_group.attrs['main_shock_location']
    after_shocks_locations = main_shock_group['aftershocks_locations'][()]
    after_shocks_locations = after_shocks_locations.reshape(-1, 2)  ## (NbAfterShocks, (X,Y))
    main_shock_day = main_shock_group.attrs['main_shock_day']
    main_shock_mag = main_shock_group.attrs['main_shock_magnitude']

    # Calculate the interpolation grid
    min_lat, max_lat, min_lon, max_lon, n_pixels_lat, n_pixels_lon = calculate_interpolation_grid(
        main_shock_location, cell_size_degs, int(num_cells / 2)
    )

    # Number of stations inside the grid
    n_stations_inside_grid = ((stations_positions[:, 0] >= min_lat) & (stations_positions[:, 0] <= max_lat) &
                              (stations_positions[:, 1] >= min_lon) & (stations_positions[:, 1] <= max_lon)).sum()

    # Skip if not enough stations
    if n_stations_inside_grid < min_stations_inside:
        n_seq_discarded += 1
        print('Skipping:', id_seq, 'with only', n_stations_inside_grid, 'stations inside the grid, out of total (downloaded) ',
              stations_positions.shape[0])
        return

    # Interpolate the data
    labels = np.zeros((n_pixels_lat, n_pixels_lon))
    # discretize the aftershocks 
    aftershocks_rows = ((after_shocks_locations[:, 0] - min_lat) / cell_size_degs).astype('int')
    aftershocks_cols = ((after_shocks_locations[:, 1] - min_lon) / cell_size_degs).astype('int')
    # mask to make sure no event is outside the grid
    aftershocks_mask = (aftershocks_rows < n_pixels_lat) & (aftershocks_rows >= 0) & (aftershocks_cols < n_pixels_lon) & (
            aftershocks_cols >= 0)
    aftershocks_rows = aftershocks_rows[aftershocks_mask]
    aftershocks_cols = aftershocks_cols[aftershocks_mask]
    if aftershocks_mask.sum() == 0:
        n_seq_discarded += 1
        print('Skipping:', id_seq, 'with no aftershocks inside the grid')
        return
    if soft_labels:
        utilities.create_soft_labels(labels, aftershocks_rows, aftershocks_cols, cell_size_rads,
                                     sigma_softlabels * cell_size_rads)
    else:
        labels[aftershocks_rows, aftershocks_cols] = 1

    interpolated_data = np.zeros((n_pixels_lat, n_pixels_lon, 3))
    utilities.fit_gps(
        interpolated_data,
        np.pi * stations_positions / 180,
        gps_stations_displacements,
        n_pixels_lat, n_pixels_lon,
        np.pi * min_lat / 180,
        np.pi * min_lon / 180,
        cell_size_rads,
        sigma_interpolation * cell_size_rads,
        min_w=0
    )

    #Save the interpolated data and labels to the output file
    save_interpolated_data(interpolated_data, labels, output_path, id_seq, main_shock_day, main_shock_mag)


def save_interpolated_data(interpolated_data, labels, output_path, main_shock_id, main_shock_day, main_shock_mag):
    with h5py.File(output_path, 'a') as f:
        if str(main_shock_id) in f:
            del f[str(main_shock_id)]
        grp = f.create_group(str(main_shock_id))
        grp.attrs['main_shock_day'] = main_shock_day
        grp.attrs['main_shock_magnitude'] = main_shock_mag

        grp.create_dataset('interpolated_displacement', data=interpolated_data)
        grp.create_dataset('labels', data=labels)

# %% [markdown]
# # Main

# %%
def main():
    process_main_shock_data(hdf5_in_put_file_path, hdf5_out_put_file_path)


if __name__ == '__main__':
    main()
    print('Number of sequences processed:', n_seq_init)
    print('Number of sequences discarded:', n_seq_discarded)
    print('Number of sequences kept:', n_seq_init - n_seq_discarded)
# Out:
# Processing main shock 103...
# Skipping: 103 with only 2 stations inside the grid, out of total (downloaded)  3
# Processing main shock 109...
# Skipping: 109 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 110...
# Skipping: 110 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 112...
# Skipping: 112 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 114...
# Skipping: 114 with only 2 stations inside the grid, out of total (downloaded)  4
# Processing main shock 115...
# Skipping: 115 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 116...
# Skipping: 116 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 150...
# Skipping: 150 with only 1 stations inside the grid, out of total (downloaded)  3
# Processing main shock 156...
# Skipping: 156 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 168...
# Skipping: 168 with only 1 stations inside the grid, out of total (downloaded)  4
# Processing main shock 169...
# Skipping: 169 with only 1 stations inside the grid, out of total (downloaded)  4
# Processing main shock 170...
# Skipping: 170 with only 1 stations inside the grid, out of total (downloaded)  4
# Processing main shock 172...
# Skipping: 172 with only 0 stations inside the grid, out of total (downloaded)  4
# Processing main shock 173...
# Skipping: 173 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 179...
# Skipping: 179 with only 0 stations inside the grid, out of total (downloaded)  8
# Processing main shock 186...
# Skipping: 186 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 187...
# Skipping: 187 with only 0 stations inside the grid, out of total (downloaded)  6
# Processing main shock 188...
# Skipping: 188 with only 0 stations inside the grid, out of total (downloaded)  6
# Processing main shock 189...
# Skipping: 189 with only 1 stations inside the grid, out of total (downloaded)  6
# Processing main shock 190...
# Skipping: 190 with only 0 stations inside the grid, out of total (downloaded)  6
# Processing main shock 191...
# Skipping: 191 with only 1 stations inside the grid, out of total (downloaded)  13
# Processing main shock 194...
# Skipping: 194 with only 1 stations inside the grid, out of total (downloaded)  3
# Processing main shock 199...
# Skipping: 199 with only 1 stations inside the grid, out of total (downloaded)  3
# Processing main shock 200...
# Skipping: 200 with only 0 stations inside the grid, out of total (downloaded)  7
# Processing main shock 202...
# Processing main shock 203...
# Skipping: 203 with only 0 stations inside the grid, out of total (downloaded)  4
# Processing main shock 204...
# Processing main shock 206...
# Skipping: 206 with no aftershocks inside the grid
# Processing main shock 207...
# Skipping: 207 with only 2 stations inside the grid, out of total (downloaded)  8
# Processing main shock 210...
# Skipping: 210 with only 2 stations inside the grid, out of total (downloaded)  4
# Processing main shock 215...
# Skipping: 215 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 217...
# Skipping: 217 with no aftershocks inside the grid
# Processing main shock 218...
# Skipping: 218 with only 1 stations inside the grid, out of total (downloaded)  10
# Processing main shock 220...
# Processing main shock 224...
# Skipping: 224 with only 0 stations inside the grid, out of total (downloaded)  4
# Processing main shock 225...
# Skipping: 225 with only 0 stations inside the grid, out of total (downloaded)  4
# Processing main shock 227...
# Skipping: 227 with only 0 stations inside the grid, out of total (downloaded)  4
# Processing main shock 246...
# Skipping: 246 with no aftershocks inside the grid
# Processing main shock 248...
# Skipping: 248 with only 1 stations inside the grid, out of total (downloaded)  9
# Processing main shock 262...
# Processing main shock 265...
# Skipping: 265 with only 2 stations inside the grid, out of total (downloaded)  13
# Processing main shock 267...
# Skipping: 267 with only 2 stations inside the grid, out of total (downloaded)  4
# Processing main shock 270...
# Processing main shock 271...
# Skipping: 271 with only 1 stations inside the grid, out of total (downloaded)  27
# Processing main shock 272...
# Skipping: 272 with only 1 stations inside the grid, out of total (downloaded)  27
# Processing main shock 273...
# Processing main shock 274...
# Skipping: 274 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 275...
# Processing main shock 277...
# Processing main shock 278...
# Processing main shock 279...
# Skipping: 279 with only 1 stations inside the grid, out of total (downloaded)  25
# Processing main shock 281...
# Skipping: 281 with only 0 stations inside the grid, out of total (downloaded)  25
# Processing main shock 282...
# Skipping: 282 with no aftershocks inside the grid
# Processing main shock 283...
# Skipping: 283 with only 2 stations inside the grid, out of total (downloaded)  18
# Processing main shock 284...
# Skipping: 284 with only 0 stations inside the grid, out of total (downloaded)  14
# Processing main shock 285...
# Skipping: 285 with only 0 stations inside the grid, out of total (downloaded)  14
# Processing main shock 286...
# Skipping: 286 with only 0 stations inside the grid, out of total (downloaded)  16
# Processing main shock 292...
# Processing main shock 293...
# Skipping: 293 with no aftershocks inside the grid
# Processing main shock 301...
# Processing main shock 303...
# Processing main shock 306...
# Skipping: 306 with only 0 stations inside the grid, out of total (downloaded)  38
# Processing main shock 309...
# Skipping: 309 with no aftershocks inside the grid
# Processing main shock 311...
# Processing main shock 315...
# Skipping: 315 with no aftershocks inside the grid
# Processing main shock 317...
# Processing main shock 321...
# Skipping: 321 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 322...
# Skipping: 322 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 325...
# Skipping: 325 with only 0 stations inside the grid, out of total (downloaded)  71
# Processing main shock 326...
# Skipping: 326 with only 0 stations inside the grid, out of total (downloaded)  62
# Processing main shock 327...
# Skipping: 327 with only 0 stations inside the grid, out of total (downloaded)  82
# Processing main shock 328...
# Skipping: 328 with only 0 stations inside the grid, out of total (downloaded)  77
# Processing main shock 329...
# Skipping: 329 with only 0 stations inside the grid, out of total (downloaded)  103
# Processing main shock 330...
# Skipping: 330 with only 0 stations inside the grid, out of total (downloaded)  65
# Processing main shock 331...
# Skipping: 331 with only 0 stations inside the grid, out of total (downloaded)  73
# Processing main shock 332...
# Skipping: 332 with only 0 stations inside the grid, out of total (downloaded)  90
# Processing main shock 333...
# Skipping: 333 with only 0 stations inside the grid, out of total (downloaded)  102
# Processing main shock 334...
# Skipping: 334 with only 0 stations inside the grid, out of total (downloaded)  156
# Processing main shock 335...
# Processing main shock 336...
# Processing main shock 337...
# Processing main shock 338...
# Skipping: 338 with only 2 stations inside the grid, out of total (downloaded)  171
# Processing main shock 339...
# Processing main shock 340...
# Skipping: 340 with only 0 stations inside the grid, out of total (downloaded)  139
# Processing main shock 341...
# Processing main shock 342...
# Processing main shock 343...
# Processing main shock 344...
# Processing main shock 345...
# Skipping: 345 with only 0 stations inside the grid, out of total (downloaded)  106
# Processing main shock 346...
# Processing main shock 348...
# Skipping: 348 with only 0 stations inside the grid, out of total (downloaded)  14
# Processing main shock 349...
# Skipping: 349 with only 0 stations inside the grid, out of total (downloaded)  160
# Processing main shock 350...
# Skipping: 350 with only 0 stations inside the grid, out of total (downloaded)  34
# Processing main shock 351...
# Skipping: 351 with only 0 stations inside the grid, out of total (downloaded)  121
# Processing main shock 352...
# Processing main shock 354...
# Skipping: 354 with only 0 stations inside the grid, out of total (downloaded)  101
# Processing main shock 355...
# Skipping: 355 with only 0 stations inside the grid, out of total (downloaded)  165
# Processing main shock 356...
# Skipping: 356 with only 0 stations inside the grid, out of total (downloaded)  119
# Processing main shock 358...
# Processing main shock 359...
# Processing main shock 360...
# Skipping: 360 with only 0 stations inside the grid, out of total (downloaded)  126
# Processing main shock 361...
# Skipping: 361 with only 0 stations inside the grid, out of total (downloaded)  121
# Processing main shock 362...
# Processing main shock 364...
# Processing main shock 365...
# Skipping: 365 with only 0 stations inside the grid, out of total (downloaded)  106
# Processing main shock 366...
# Skipping: 366 with only 0 stations inside the grid, out of total (downloaded)  103
# Processing main shock 367...
# Processing main shock 368...
# Skipping: 368 with only 0 stations inside the grid, out of total (downloaded)  155
# Processing main shock 369...
# Processing main shock 370...
# Processing main shock 371...
# Skipping: 371 with only 0 stations inside the grid, out of total (downloaded)  160
# Processing main shock 372...
# Skipping: 372 with only 1 stations inside the grid, out of total (downloaded)  166
# Processing main shock 373...
# Processing main shock 374...
# Skipping: 374 with only 0 stations inside the grid, out of total (downloaded)  161
# Processing main shock 375...
# Skipping: 375 with only 2 stations inside the grid, out of total (downloaded)  181
# Processing main shock 376...
# Processing main shock 377...
# Skipping: 377 with only 0 stations inside the grid, out of total (downloaded)  104
# Processing main shock 378...
# Skipping: 378 with no aftershocks inside the grid
# Processing main shock 379...
# Skipping: 379 with only 1 stations inside the grid, out of total (downloaded)  118
# Processing main shock 380...
# Skipping: 380 with only 1 stations inside the grid, out of total (downloaded)  109
# Processing main shock 381...
# Skipping: 381 with only 0 stations inside the grid, out of total (downloaded)  107
# Processing main shock 382...
# Processing main shock 383...
# Skipping: 383 with only 0 stations inside the grid, out of total (downloaded)  169
# Processing main shock 384...
# Processing main shock 385...
# Skipping: 385 with only 0 stations inside the grid, out of total (downloaded)  175
# Processing main shock 386...
# Processing main shock 387...
# Skipping: 387 with only 0 stations inside the grid, out of total (downloaded)  138
# Processing main shock 388...
# Processing main shock 389...
# Skipping: 389 with only 0 stations inside the grid, out of total (downloaded)  127
# Processing main shock 390...
# Skipping: 390 with only 0 stations inside the grid, out of total (downloaded)  147
# Processing main shock 391...
# Skipping: 391 with only 0 stations inside the grid, out of total (downloaded)  152
# Processing main shock 392...
# Processing main shock 393...
# Skipping: 393 with only 0 stations inside the grid, out of total (downloaded)  105
# Processing main shock 394...
# Processing main shock 395...
# Skipping: 395 with only 0 stations inside the grid, out of total (downloaded)  87
# Processing main shock 396...
# Processing main shock 398...
# Processing main shock 399...
# Skipping: 399 with only 0 stations inside the grid, out of total (downloaded)  80
# Processing main shock 400...
# Processing main shock 401...
# Processing main shock 402...
# Processing main shock 403...
# Processing main shock 404...
# Processing main shock 405...
# Skipping: 405 with only 0 stations inside the grid, out of total (downloaded)  169
# Processing main shock 406...
# Skipping: 406 with only 0 stations inside the grid, out of total (downloaded)  136
# Processing main shock 407...
# Processing main shock 408...
# Processing main shock 409...
# Processing main shock 410...
# Processing main shock 411...
# Processing main shock 412...
# Processing main shock 413...
# Skipping: 413 with only 0 stations inside the grid, out of total (downloaded)  84
# Processing main shock 414...
# Skipping: 414 with only 0 stations inside the grid, out of total (downloaded)  71
# Processing main shock 415...
# Skipping: 415 with only 0 stations inside the grid, out of total (downloaded)  111
# Processing main shock 416...
# Processing main shock 417...
# Processing main shock 418...
# Skipping: 418 with only 0 stations inside the grid, out of total (downloaded)  41
# Processing main shock 419...
# Skipping: 419 with only 0 stations inside the grid, out of total (downloaded)  39
# Processing main shock 420...
# Skipping: 420 with only 0 stations inside the grid, out of total (downloaded)  76
# Processing main shock 421...
# Processing main shock 422...
# Processing main shock 423...
# Skipping: 423 with only 0 stations inside the grid, out of total (downloaded)  85
# Processing main shock 424...
# Processing main shock 425...
# Processing main shock 426...
# Processing main shock 427...
# Processing main shock 428...
# Processing main shock 429...
# Skipping: 429 with only 0 stations inside the grid, out of total (downloaded)  29
# Processing main shock 430...
# Processing main shock 431...
# Skipping: 431 with only 1 stations inside the grid, out of total (downloaded)  201
# Processing main shock 432...
# Processing main shock 433...
# Skipping: 433 with only 1 stations inside the grid, out of total (downloaded)  154
# Processing main shock 434...
# Skipping: 434 with only 0 stations inside the grid, out of total (downloaded)  146
# Processing main shock 437...
# Processing main shock 438...
# Skipping: 438 with no aftershocks inside the grid
# Processing main shock 440...
# Processing main shock 445...
# Processing main shock 446...
# Processing main shock 447...
# Skipping: 447 with no aftershocks inside the grid
# Processing main shock 448...
# Skipping: 448 with only 0 stations inside the grid, out of total (downloaded)  102
# Processing main shock 449...
# Skipping: 449 with only 0 stations inside the grid, out of total (downloaded)  100
# Processing main shock 452...
# Skipping: 452 with no aftershocks inside the grid
# Processing main shock 454...
# Processing main shock 457...
# Skipping: 457 with only 0 stations inside the grid, out of total (downloaded)  116
# Processing main shock 458...
# Skipping: 458 with only 0 stations inside the grid, out of total (downloaded)  57
# Processing main shock 459...
# Skipping: 459 with only 0 stations inside the grid, out of total (downloaded)  59
# Processing main shock 460...
# Skipping: 460 with no aftershocks inside the grid
# Processing main shock 461...
# Skipping: 461 with no aftershocks inside the grid
# Processing main shock 463...
# Skipping: 463 with only 0 stations inside the grid, out of total (downloaded)  111
# Processing main shock 467...
# Skipping: 467 with no aftershocks inside the grid
# Processing main shock 468...
# Processing main shock 472...
# Processing main shock 484...
# Processing main shock 489...
# Processing main shock 491...
# Skipping: 491 with only 1 stations inside the grid, out of total (downloaded)  121
# Processing main shock 493...
# Skipping: 493 with no aftershocks inside the grid
# Processing main shock 494...
# Skipping: 494 with no aftershocks inside the grid
# Processing main shock 495...
# Processing main shock 496...
# Skipping: 496 with only 0 stations inside the grid, out of total (downloaded)  136
# Processing main shock 504...
# Processing main shock 505...
# Skipping: 505 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 515...
# Processing main shock 521...
# Processing main shock 522...
# Processing main shock 526...
# Skipping: 526 with only 1 stations inside the grid, out of total (downloaded)  3
# Processing main shock 527...
# Skipping: 527 with only 0 stations inside the grid, out of total (downloaded)  118
# Processing main shock 528...
# Skipping: 528 with only 0 stations inside the grid, out of total (downloaded)  127
# Processing main shock 531...
# Skipping: 531 with only 0 stations inside the grid, out of total (downloaded)  138
# Processing main shock 534...
# Processing main shock 535...
# Processing main shock 537...
# Skipping: 537 with no aftershocks inside the grid
# Processing main shock 538...
# Skipping: 538 with only 1 stations inside the grid, out of total (downloaded)  20
# Processing main shock 539...
# Skipping: 539 with only 0 stations inside the grid, out of total (downloaded)  3
# Processing main shock 540...
# Skipping: 540 with only 0 stations inside the grid, out of total (downloaded)  28
# Processing main shock 542...
# Skipping: 542 with only 0 stations inside the grid, out of total (downloaded)  54
# Processing main shock 544...
# Skipping: 544 with only 2 stations inside the grid, out of total (downloaded)  15
# Processing main shock 547...
# Processing main shock 548...
# Processing main shock 549...
# Processing main shock 550...
# Processing main shock 556...
# Processing main shock 565...
# Skipping: 565 with only 0 stations inside the grid, out of total (downloaded)  38
# Processing main shock 567...
# Processing main shock 568...
# Skipping: 568 with only 0 stations inside the grid, out of total (downloaded)  150
# Processing main shock 576...
# Processing main shock 577...
# Number of sequences processed: 226
# Number of sequences discarded: 139
# Number of sequences kept: 87
