# %%
import os
from importlib import reload

import h5py
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import haversine_distances

import utilities

reload(utilities)
# Out:
# <module 'utilities' from '/mnt/beegfs/projects/corrQuake/earthquakes/New_code/utilities.py'>

# %% [markdown]
# # Functions

# %%
def filter_spatio_temporally_close_mainshocks(mainshocks_days_dict, mainshocks_locations_dict, grid_size_km,
                                              min_days_between_mainshocks):
    """ Filter main shocks that are close in space and time, keeping only the one that happened first. """
    earth_radius_km = 6371  # km
    filtered_keys = set(mainshocks_days_dict.keys())  # Start with all keys
    to_remove = set()

    keys = sorted(mainshocks_days_dict.keys(), key=lambda x: mainshocks_days_dict[x])  # Sort keys by date

    # Compare each pair of main shocks
    n_keys = len(keys)
    print(f"Number of main shocks: {n_keys}")
    for i in range(n_keys - 1):
        for j in range(i + 1, n_keys):
            key_i, key_j = keys[i], keys[j]
            if key_i in to_remove or key_j in to_remove:
                continue  # Skip if already marked for removal

            day_i, day_j = mainshocks_days_dict[key_i], mainshocks_days_dict[key_j]
            loc_i, loc_j = mainshocks_locations_dict[key_i], mainshocks_locations_dict[key_j]

            # Calculate spatial distance
            distance = haversine_distances(np.radians(loc_i).reshape(-1, 2),
                                           np.radians(loc_j).reshape(-1, 2)) * earth_radius_km

            # Check if they are close in space and time
            if (distance <= np.sqrt(2) * grid_size_km / 2) and ((day_j - day_i) < np.timedelta64(
                    min_days_between_mainshocks, 'D')):
                to_remove.add(key_j)  # Remove the later one

    # Update filtered keys by removing those marked
    filtered_keys.difference_update(to_remove)
    print(f"Number of main shocks after filtering spatiotemporally close mainshocks: {len(filtered_keys)}")
    return filtered_keys


def filter_gps_stations(earthquakes, ngl_list, search_radius, min_mainshock_mag, min_stations_per_main_shock, region):
    """ 
    Filter GPS stations based on their distance to the main shocks 
    and the number of stations around each main shock.
    Morally, 'earthquakes' is the catalog, with labeled sequences (in 'seq_id')
    ngl_list: metadata of the GPS stations
    """
    stations_to_download = set()
    mainshocks_stations = {}
    mainshocks_days = {}
    main_shocks_locations = {}
    region_min_lat, region_max_lat, region_min_lon, region_max_lon = utilities.return_regions()[region]
    earth_radius_km = 6371  # km

    for id_seq, seq in earthquakes.groupby('seq_id'):
        if len(seq) <= 1:
            continue
        mainshock = seq[(seq['type'] == 1) & (seq['mag'] >= min_mainshock_mag) & (seq['lat'] >= region_min_lat) & (
                seq['lat'] <= region_max_lat) & (seq['lon'] >= region_min_lon) & (seq['lon'] <= region_max_lon)]
        if mainshock.empty:
            continue
        # max_radius = max(10 ** (mainshock.mag.values[0] / 2 - 0.79),
        #                 search_radius)  # We ensure a minimum search radius of search_radius km
        ## ngl_list[["lat", "lon"]] : position of the station, at no specific day, at ~1km precision (is enough for now)
        distances = haversine_distances(np.radians(ngl_list[["lat", "lon"]]),
                                        np.radians(mainshock[["lat", "lon"]].values))[:, 0]
        distances *= earth_radius_km
        ## distances : list of all distances station-mainshock
        mainshock_day = mainshock.day.values[0]
        mainshock_location = mainshock[['lat', 'lon']].values[0]
        main_shocks_locations[id_seq] = mainshock_location
        # We only consider stations that were active n_days_before_mainshock days before the main shock 
        # and n_days_after_mainshock days after and that are within the max_radius distance from the main shock
        valid_mask = (distances <= search_radius) & (
                ngl_list.begin.values <= (mainshock_day - np.timedelta64(n_days_before_mainshock, 'D'))) & (
                             ngl_list.end.values >= (mainshock_day + np.timedelta64(n_days_after_mainshock,
                                                                                    'D')))

        valid_stations = ngl_list.name[valid_mask]
        if len(valid_stations) >= min_stations_per_main_shock:
            stations_to_download.update(valid_stations)
            mainshocks_stations[id_seq] = list(valid_stations)
            mainshocks_days[id_seq] = mainshock_day

    ## filter mainshocks that are too close in space and time
    filtered_keys = filter_spatio_temporally_close_mainshocks(mainshocks_days, main_shocks_locations, grid_size_km,
                                                              min_days_between_mainshocks)
    mainshocks_stations = {k: mainshocks_stations[k] for k in filtered_keys}
    mainshocks_days = {k: mainshocks_days[k] for k in filtered_keys}
    return stations_to_download, mainshocks_stations, mainshocks_days


def download_and_filter_gps_data(stations_to_download, gps_data_output_path, mainshocks_stations, mainshocks_days,
                                 n_days_before_mainshock, n_days_after_mainshock, ngl_list,
                                 mainshocks_gps_stations_daily_positions_path=""):
    """
    Download and filter GPS data for the stations around the main shocks. 
    
    """
    if os.path.exists(mainshocks_gps_stations_daily_positions_path):
        mainshocks_gps_stations_daily_positions = joblib.load(mainshocks_gps_stations_daily_positions_path)
        return mainshocks_gps_stations_daily_positions
    mainshocks_gps_stations_daily_positions = {}  ## GPS data at all relevant days, for each given mainshock
    if not stations_to_download:
        raise ValueError("No stations to download.")

    # We calculate the median latitude and longitude of the stations to download to use as a reference point
    # of the region
    filtered_ngl_list = ngl_list[ngl_list.name.isin(stations_to_download)]
    center_lat = filtered_ngl_list['lat'].median()
    center_lon = filtered_ngl_list['lon'].median()
    #print(f"Center of the region: {center_lat}, {center_lon}")
    # sys.exit()
    ## median of all stations seen in all mainshocks, i.e. approximately center of Japan

    # Load or download data for each station once and store it in a dictionary
    ## TODO station_data: rename into station_daily_positions TODO!
    stations_daily_positions = {}
    for station in stations_to_download:
        file_path = os.path.join(gps_data_output_path, f"{station}.csv")
        if os.path.exists(file_path):
            ## TIODO: rename data to: one_station_daily_positions
            one_station_daily_positions = pd.read_csv(file_path, sep=" ", parse_dates=['date'])
            print(f"{station} data loaded.")
        else:
            try:
                one_station_daily_positions = utilities.get_ngl_gps_data(station, "tenv3")
                #                 haversine_distances(data_in_rads, (center_lat, center_lon)) ## TODO: consider computing 
                ## the distance with the exact (haversine) formula
                utilities.convert_lat_lon_to_km(one_station_daily_positions, center_lat, center_lon)
                ## data[km_lat] and data[km_lon] are now filled
                one_station_daily_positions.to_csv(file_path, sep=" ", index=False)
                print(f"{station} data downloaded and saved.")
            except Exception as e:
                raise Exception(f"Error downloading data for station {station}: {e}")

        stations_daily_positions[station] = one_station_daily_positions  ## temporary dict

    # Pre-calculate the date ranges for each main shock
    mainshock_date_ranges = {
        id_seq: (
            mainshocks_days[id_seq] - np.timedelta64(n_days_before_mainshock, 'D'),
            mainshocks_days[id_seq] + np.timedelta64(n_days_after_mainshock, 'D')
        )
        for id_seq in mainshocks_days.keys()
    }

    # Process each main shock
    for id_seq, stations in mainshocks_stations.items():
        start_date, end_date = mainshock_date_ranges[id_seq]
        directory_path = f"{gps_data_output_path}/Sequence_{id_seq}"
        os.makedirs(directory_path, exist_ok=True)

        for station in stations:
            if station not in stations_daily_positions:
                raise ValueError(f"Data for station {station} not found.")

            ## subdata: morally, the GPS data restricted to a window, for 1 mainshock
            ## TODO: reanme subdata into oneMS_restrictedWindow_dailyPosition
            one_station_daily_positions_restricted_window_path = f"{directory_path}/{station}_positions.csv"
            if os.path.exists(one_station_daily_positions_restricted_window_path):
                one_station_daily_positions_restricted_window = pd.read_csv(
                    one_station_daily_positions_restricted_window_path, sep=" ", parse_dates=['date'])
                ## TODO: Remove the code below, it's not necessary
                one_station_daily_positions_restricted_window = one_station_daily_positions_restricted_window[
                    (one_station_daily_positions_restricted_window['date'] >= start_date) & (
                            one_station_daily_positions_restricted_window['date'] <= end_date)]

                print(f"{station} subdata around main shock {id_seq} loaded.")
            else:
                one_station_daily_positions = stations_daily_positions[station]
                one_station_daily_positions_restricted_window = one_station_daily_positions[
                    (one_station_daily_positions['date'] >= start_date) & (
                            one_station_daily_positions['date'] <= end_date)]
                one_station_daily_positions_restricted_window = one_station_daily_positions_restricted_window.sort_values(
                    by='date')

                if (
                        len(one_station_daily_positions_restricted_window) == n_days_before_mainshock + 1 + n_days_after_mainshock) and np.isfinite(
                    one_station_daily_positions_restricted_window[
                        ['lat', 'lon', 'z', 'km_lat', 'km_lon']].values).all():
                    one_station_daily_positions_restricted_window.to_csv(
                        one_station_daily_positions_restricted_window_path, sep=" ", index=False)
                    print(f"{station} subdata around main shock {id_seq} saved.")
                else:
                    print(f"Data of station {station} around main shock {id_seq} is incomplete or contains NaNs.")
                    continue

            if id_seq not in mainshocks_gps_stations_daily_positions:
                mainshocks_gps_stations_daily_positions[id_seq] = []
            mainshocks_gps_stations_daily_positions[id_seq].append(one_station_daily_positions_restricted_window)

    joblib.dump(mainshocks_gps_stations_daily_positions, mainshocks_gps_stations_daily_positions_path)
    return mainshocks_gps_stations_daily_positions


#converted_first2 = []
#haversined2 = []
def process_and_save_main_shocks_data(mainshocks_gps_stations_daily_positions, mainshocks_days, earthquakes,
                                      min_after_shock_mag,
                                      after_shock_time_window,
                                      n_days_after_mainshock,
                                      hdf5_output_file_path,
                                      min_stations_per_main_shock):
    """ Process and save the main shocks data to the HDF5 file. """
    earth_radius_km = 6371  # km
    km_per_degree_lat = np.pi * earth_radius_km / 180.0
    for id_seq, ms_gps_stations_positions in mainshocks_gps_stations_daily_positions.items():
        #converted_first = []
        #haversined = []
        print(f"Processing main shock {id_seq}...")
        displacements = []
        stations_positions = []

        # Extract aftershocks information
        seq = earthquakes[earthquakes.seq_id == id_seq]  ## all EQs of that sequence
        mainshock = seq[seq['type'] == 1 & (seq['day'] == mainshocks_days[id_seq])]
        # Filter aftershocks
        aftershocks = seq[(seq['type'] == 2) & (
                seq['day'] > mainshocks_days[id_seq] + np.timedelta64(n_days_after_mainshock, 'D')) & (
                                  seq['day'] <= mainshocks_days[id_seq] + np.timedelta64(after_shock_time_window, 'D'))
                          & (seq['mag'] >= min_after_shock_mag)]
        ## TODO: make a plot of the time , with MS day as a marker, and AS that are kept as markers too, with ticks at each days
        if len(aftershocks) < 1: continue
        mainshock_location = mainshock[['lat', 'lon']].values[0]
        #         station_aftershocks_locations : TODO: rename into oneMS_aftershocksLocations
        one_ms_aftershocks_locations = aftershocks[['lat', 'lon']].values
        #         station_aftershocks_mags : TODO: rename into oneMS_aftershocksMags
        one_ms_aftershocks_mags = aftershocks['mag'].values

        # loop over all stations of a given main shock, and for each compute the displacements
        for gps_station_positions in ms_gps_stations_positions:
            station_position = \
                gps_station_positions[
                    gps_station_positions['date'] == mainshocks_days[id_seq] - np.timedelta64(1, 'D')][
                    ['lat', 'lon']].values[0]  ## position of the station at day -1 
            stations_positions.append(station_position)
            ## TODO: check if maybe, converting to km first induces more numerical errors
            ## OR, directly, replace this code with minus operators to compute distances,
            ## replace it with haversine distnance (between position at day 0 and at day 1)
            ## haversine (lat_station_day-1, lon_staiton_day-1, lat_station_day+1, lon_station_day+1)
            # dis_lat = (
            #         gps_station_positions['km_lat'].shift(-1) - gps_station_positions['km_lat'].shift(1)
            # ).dropna().values
            # 
            # dis_lon = (
            #         gps_station_positions['km_lon'].shift(-1) - gps_station_positions['km_lon'].shift(1)
            # ).dropna().values
            # 
            # dis_z = (
            #         gps_station_positions['z'].shift(-1) - gps_station_positions['z'].shift(1)
            # ).dropna().values

            dis_lat = (
                    gps_station_positions['lat'].shift(-1) - gps_station_positions['lat'].shift(1)
            ).dropna().values
            dis_lat *= km_per_degree_lat  ## convert to km
            origin_lat = gps_station_positions['lat'].median()
            km_per_degree_lon = km_per_degree_lat * np.cos(np.radians(origin_lat))
            dis_lon = (
                    gps_station_positions['lon'].shift(-1) - gps_station_positions['lon'].shift(1)
            ).dropna().values
            dis_lon *= km_per_degree_lon  ## convert to km
            dis_z = (
                    gps_station_positions['z'].shift(-1) - gps_station_positions['z'].shift(1)
            ).dropna().values

            # Stack the displacements into a single numpy array
            # Each column corresponds to a displacement dimension (lat, lon, z)
            station_displacements = np.stack((dis_lat, dis_lon, dis_z), axis=-1)
            #print(dis_lat)
            #print(dis_lon)
            #print(dis_z)
            #print(station_displacements)
            #sys.exit()
            if not np.isfinite(station_displacements).all(): continue
            displacements.append(station_displacements)

        #     tmp1 = np.radians(gps_station_positions[['lat', 'lon']].shift(-1).dropna().values)
        #     tmp2 = np.radians(gps_station_positions[['lat', 'lon']].shift(1).dropna().values)
        #     distances = 6371 * haversine_distances(tmp1[1].reshape(-1,2), tmp2[1].reshape(-1,2))
        #     converted_first.append(np.linalg.norm(displacements[0][:, 0:2], axis=1).flatten())
        #     haversined.append(distances.flatten())
        # converted_first2.append(converted_first)
        # haversined2.append(haversined)
        #sys.exit()
        if len(displacements) < min_stations_per_main_shock: continue  ##TODO: put 3 as a parameter
        # Save to HDF5
        with h5py.File(hdf5_output_file_path, 'a') as f:
            if str(id_seq) in f:
                del f[str(id_seq)]
            grp = f.create_group(str(id_seq))
            grp.attrs['main_shock_day'] = str(np.datetime_as_string(mainshocks_days[id_seq], unit='D'))
            grp.attrs['main_shock_magnitude'] = mainshock.mag.values[0]
            grp.attrs['main_shock_location'] = mainshock_location

            grp.create_dataset('gps_stations_displacements', data=np.array(displacements))
            grp.create_dataset('stations_positions', data=np.vstack(stations_positions))
            grp.create_dataset('aftershocks_magnitudes', data=one_ms_aftershocks_mags)
            grp.create_dataset('aftershocks_locations', data=one_ms_aftershocks_locations)

# %% [markdown]
# # Parameters

# %%
earthquakes_path = "custom_catalog.csv"  #Path to the earthquake catalog file
search_radius = 300  #Search radius of GPS stations in km
min_mainshock_mag = 6  #Minimum magnitude of mainshocks to consider
min_stations_per_main_shock = 3  #Minimum number of GPS stations around a mainshock to consider it
regression = True  #Whether to use regression or classification
if regression:
    min_after_shock_mag = 2.5  #Minimum magnitude of aftershocks to consider
else:
    min_after_shock_mag = 4
after_shock_time_window = 45  #Days after the mainshock to search for aftershocks
n_days_before_mainshock = 1  #Number of days before the mainshock to consider
n_days_after_mainshock = 1  #Number of days after the mainshock to consider
min_days_between_mainshocks = 30  #Minimum number of days between two mainshocks to consider them as separate events
grid_size_km = 250  # Size of the square grid in km 
# path to the hdf5 file to store the data for the main shocks
hdf5_output_file_path = f"Data/Displacements_min_mainshock_mag={min_mainshock_mag}_min_stations_per_main_shock={min_stations_per_main_shock}_regression={regression}_min_after_shock_mag={min_after_shock_mag}_after_shock_time_window={after_shock_time_window}_n_days_before_mainshock={n_days_before_mainshock}_n_days_after_mainshock={n_days_after_mainshock}_min_days_between_mainshocks={min_days_between_mainshocks}_grid_size_km={grid_size_km}.hdf5"
# path to the dictionary containing the GPS data for the stations around the main shocks
dict_mainshocks_gps_stations_daily_positions_path = "Data/dict_mainshocks_gps_stations_daily_positions.pkl"
region = 'Japan'  # Region of the main shocks

# %% [markdown]
# # Main

# %%
# utilities.initialize_hdf5(hdf5_output_file_path) # not necessary, the file is created when the first main shock is processed

## load catalog
earthquakes = pd.read_csv(earthquakes_path, sep=" ", parse_dates=['datetime'])
earthquakes.rename(columns={'datetime': 'day'}, inplace=True)
earthquakes['day'] = earthquakes.day.values.astype('datetime64[D]')
earthquakes.sort_values(by='day', inplace=True)
earthquakes.reset_index(drop=True, inplace=True)

## load list of stations (all available stations, many that are not used)
gps_data_output_path = "Data"  #Path to store the GPS data
ngl_list = utilities.get_ngl_stations(f'{gps_data_output_path}/ngl_list.csv')
# Out:
# ngl stations already downloaded

# %%
## detect which stations are relevant
stations_to_download, mainshocks_stations, mainshocks_days = filter_gps_stations(earthquakes, ngl_list,
                                                                                 search_radius, min_mainshock_mag,
                                                                                 min_stations_per_main_shock, region)
# Out:
# Number of main shocks: 319
# Number of main shocks after filtering spatiotemporally close mainshocks: 179

# %%
## download stations' data (positions) and filter by day-windows
## if csv's are in the proper location, then no download is node and it's very fast
mainshocks_gps_stations_daily_positions = download_and_filter_gps_data(stations_to_download, gps_data_output_path,
                                                                       mainshocks_stations,
                                                                       mainshocks_days, n_days_before_mainshock,
                                                                       n_days_after_mainshock,
                                                                       ngl_list,
                                                                       dict_mainshocks_gps_stations_daily_positions_path)
# Out:
# G136 data downloaded and saved.
# G115 data downloaded and saved.
# G148 data downloaded and saved.
# G174 data downloaded and saved.
# J427 data downloaded and saved.
# J192 data downloaded and saved.
# J647 data downloaded and saved.
# CHNT data downloaded and saved.
# R008 data downloaded and saved.
# J556 data downloaded and saved.
# J301 data downloaded and saved.
# J916 data downloaded and saved.
# R011 data downloaded and saved.
# Z202 data downloaded and saved.
# J336 data downloaded and saved.
# G001 data downloaded and saved.
# TAIP data downloaded and saved.
# J731 data downloaded and saved.
# J010 data downloaded and saved.
# J065 data downloaded and saved.
# J165 data downloaded and saved.
# G061 data downloaded and saved.
# G209 data downloaded and saved.
# J244 data downloaded and saved.
# NAAO data downloaded and saved.
# I071 data downloaded and saved.
# J550 data downloaded and saved.
# J421 data downloaded and saved.
# STKW data downloaded and saved.
# J068 data downloaded and saved.
# I086 data downloaded and saved.
# J555 data downloaded and saved.
# J295 data downloaded and saved.
# J613 data downloaded and saved.
# NSHE data downloaded and saved.
# J990 data downloaded and saved.
# TWTF data downloaded and saved.
# G106 data downloaded and saved.
# J857 data downloaded and saved.
# G044 data downloaded and saved.
# J770 data downloaded and saved.
# J014 data downloaded and saved.
# J464 data downloaded and saved.
# J409 data downloaded and saved.
# I101 data downloaded and saved.
# J505 data downloaded and saved.
# Z210 data downloaded and saved.
# JYAN data downloaded and saved.
# G017 data downloaded and saved.
# J397 data downloaded and saved.
# S063 data downloaded and saved.
# I004 data downloaded and saved.
# J005 data downloaded and saved.
# I036 data downloaded and saved.
# G084 data downloaded and saved.
# G028 data downloaded and saved.
# I064 data downloaded and saved.
# J485 data downloaded and saved.
# J922 data downloaded and saved.
# J324 data downloaded and saved.
# J561 data downloaded and saved.
# J760 data downloaded and saved.
# J831 data downloaded and saved.
# I010 data downloaded and saved.
# J398 data downloaded and saved.
# I032 data downloaded and saved.
# I001 data downloaded and saved.
# SGUN data downloaded and saved.
# J335 data downloaded and saved.
# NGAO data downloaded and saved.
# J056 data downloaded and saved.
# G215 data downloaded and saved.
# J200 data downloaded and saved.
# J846 data downloaded and saved.
# MFEN data downloaded and saved.
# G186 data downloaded and saved.
# I023 data downloaded and saved.
# G165 data downloaded and saved.
# I049 data downloaded and saved.
# JSAN data downloaded and saved.
# J466 data downloaded and saved.
# J789 data downloaded and saved.
# X077 data downloaded and saved.
# J274 data downloaded and saved.
# J061 data downloaded and saved.
# J609 data downloaded and saved.
# NSAN data downloaded and saved.
# J395 data downloaded and saved.
# J772 data downloaded and saved.
# G169 data downloaded and saved.
# J360 data downloaded and saved.
# J489 data downloaded and saved.
# J058 data downloaded and saved.
# Z209 data downloaded and saved.
# J292 data downloaded and saved.
# J627 data downloaded and saved.
# G134 data downloaded and saved.
# J201 data downloaded and saved.
# J405 data downloaded and saved.
# J252 data downloaded and saved.
# I089 data downloaded and saved.
# J403 data downloaded and saved.
# J818 data downloaded and saved.
# J483 data downloaded and saved.
# G144 data downloaded and saved.
# G096 data downloaded and saved.
# J921 data downloaded and saved.
# J824 data downloaded and saved.
# J960 data downloaded and saved.
# R013 data downloaded and saved.
# J950 data downloaded and saved.
# J022 data downloaded and saved.
# R001 data downloaded and saved.
# SLNP data downloaded and saved.
# CCJ2 data downloaded and saved.
# G131 data downloaded and saved.
# J342 data downloaded and saved.
# I105 data downloaded and saved.
# J767 data downloaded and saved.
# J758 data downloaded and saved.
# I074 data downloaded and saved.
# Z104 data downloaded and saved.
# J915 data downloaded and saved.
# J615 data downloaded and saved.
# J520 data downloaded and saved.
# J139 data downloaded and saved.
# J341 data downloaded and saved.
# J140 data downloaded and saved.
# J985 data downloaded and saved.
# J046 data downloaded and saved.
# J219 data downloaded and saved.
# J262 data downloaded and saved.
# J385 data downloaded and saved.
# J583 data downloaded and saved.
# J063 data downloaded and saved.
# J226 data downloaded and saved.
# J868 data downloaded and saved.
# J569 data downloaded and saved.
# J617 data downloaded and saved.
# G167 data downloaded and saved.
# Z213 data downloaded and saved.
# I018 data downloaded and saved.
# J643 data downloaded and saved.
# J495 data downloaded and saved.
# J377 data downloaded and saved.
# FNGU data downloaded and saved.
# S169 data downloaded and saved.
# J581 data downloaded and saved.
# I039 data downloaded and saved.
# G117 data downloaded and saved.
# J988 data downloaded and saved.
# J696 data downloaded and saved.
# YUNL data downloaded and saved.
# J294 data downloaded and saved.
# G226 data downloaded and saved.
# J479 data downloaded and saved.
# J494 data downloaded and saved.
# ANK3 data downloaded and saved.
# J640 data downloaded and saved.
# G121 data downloaded and saved.
# J108 data downloaded and saved.
# X055 data downloaded and saved.
# J704 data downloaded and saved.
# J171 data downloaded and saved.
# J093 data downloaded and saved.
# J094 data downloaded and saved.
# J418 data downloaded and saved.
# J567 data downloaded and saved.
# J683 data downloaded and saved.
# S004 data downloaded and saved.
# J374 data downloaded and saved.
# J584 data downloaded and saved.
# J958 data downloaded and saved.
# J623 data downloaded and saved.
# J655 data downloaded and saved.
# J436 data downloaded and saved.
# J159 data downloaded and saved.
# J013 data downloaded and saved.
# I095 data downloaded and saved.
# J878 data downloaded and saved.
# J032 data downloaded and saved.
# J220 data downloaded and saved.
# J786 data downloaded and saved.
# J749 data downloaded and saved.
# J102 data downloaded and saved.
# J535 data downloaded and saved.
# J598 data downloaded and saved.
# J077 data downloaded and saved.
# J183 data downloaded and saved.
# J188 data downloaded and saved.
# G139 data downloaded and saved.
# J795 data downloaded and saved.
# S070 data downloaded and saved.
# G175 data downloaded and saved.
# J124 data downloaded and saved.
# G015 data downloaded and saved.
# J352 data downloaded and saved.
# J361 data downloaded and saved.
# I047 data downloaded and saved.
# J270 data downloaded and saved.
# J401 data downloaded and saved.
# J811 data downloaded and saved.
# HANS data downloaded and saved.
# J400 data downloaded and saved.
# J376 data downloaded and saved.
# KSHI data downloaded and saved.
# J284 data downloaded and saved.
# J860 data downloaded and saved.
# J442 data downloaded and saved.
# J800 data downloaded and saved.
# G155 data downloaded and saved.
# J719 data downloaded and saved.
# J075 data downloaded and saved.
# J517 data downloaded and saved.
# G138 data downloaded and saved.
# J052 data downloaded and saved.
# J457 data downloaded and saved.
# G166 data downloaded and saved.
# SINL data downloaded and saved.
# J222 data downloaded and saved.
# J518 data downloaded and saved.
# S058 data downloaded and saved.
# J164 data downloaded and saved.
# J111 data downloaded and saved.
# S167 data downloaded and saved.
# G083 data downloaded and saved.
# J461 data downloaded and saved.
# J447 data downloaded and saved.
# J119 data downloaded and saved.
# J537 data downloaded and saved.
# J695 data downloaded and saved.
# J692 data downloaded and saved.
# I003 data downloaded and saved.
# J123 data downloaded and saved.
# J833 data downloaded and saved.
# I084 data downloaded and saved.
# J570 data downloaded and saved.
# J417 data downloaded and saved.
# J382 data downloaded and saved.
# I079 data downloaded and saved.
# J327 data downloaded and saved.
# FIVE data downloaded and saved.
# G189 data downloaded and saved.
# J474 data downloaded and saved.
# I096 data downloaded and saved.
# R012 data downloaded and saved.
# G036 data downloaded and saved.
# DPIN data downloaded and saved.
# J236 data downloaded and saved.
# J141 data downloaded and saved.
# J959 data downloaded and saved.
# I097 data downloaded and saved.
# S048 data downloaded and saved.
# J105 data downloaded and saved.
# J761 data downloaded and saved.
# J974 data downloaded and saved.
# J723 data downloaded and saved.
# I062 data downloaded and saved.
# G113 data downloaded and saved.
# WFEN data downloaded and saved.
# G191 data downloaded and saved.
# PLA2 data downloaded and saved.
# X071 data downloaded and saved.
# J952 data downloaded and saved.
# J601 data downloaded and saved.
# J462 data downloaded and saved.
# J273 data downloaded and saved.
# X061 data downloaded and saved.
# J040 data downloaded and saved.
# I069 data downloaded and saved.
# I103 data downloaded and saved.
# J355 data downloaded and saved.
# J925 data downloaded and saved.
# I007 data downloaded and saved.
# MLYN data downloaded and saved.
# J074 data downloaded and saved.
# J735 data downloaded and saved.
# J055 data downloaded and saved.
# J304 data downloaded and saved.
# SCH7 data downloaded and saved.
# MTKA data downloaded and saved.
# J961 data downloaded and saved.
# J532 data downloaded and saved.
# LGU2 data downloaded and saved.
# J185 data downloaded and saved.
# J667 data downloaded and saved.
# J895 data downloaded and saved.
# J303 data downloaded and saved.
# J311 data downloaded and saved.
# FCWS data downloaded and saved.
# R010 data downloaded and saved.
# G142 data downloaded and saved.
# J819 data downloaded and saved.
# G211 data downloaded and saved.
# J319 data downloaded and saved.
# J812 data downloaded and saved.
# KYIN data downloaded and saved.
# J589 data downloaded and saved.
# J972 data downloaded and saved.
# J340 data downloaded and saved.
# SON3 data downloaded and saved.
# J019 data downloaded and saved.
# PNC1 data downloaded and saved.
# J947 data downloaded and saved.
# J513 data downloaded and saved.
# J913 data downloaded and saved.
# J426 data downloaded and saved.
# G152 data downloaded and saved.
# J117 data downloaded and saved.
# J801 data downloaded and saved.
# J973 data downloaded and saved.
# J887 data downloaded and saved.
# J981 data downloaded and saved.
# J771 data downloaded and saved.
# J572 data downloaded and saved.
# J384 data downloaded and saved.
# J787 data downloaded and saved.
# G161 data downloaded and saved.
# MLO2 data downloaded and saved.
# NICT data downloaded and saved.
# G101 data downloaded and saved.
# I029 data downloaded and saved.
# J048 data downloaded and saved.
# J156 data downloaded and saved.
# G058 data downloaded and saved.
# J681 data downloaded and saved.
# J431 data downloaded and saved.
# C002 data downloaded and saved.
# J182 data downloaded and saved.
# J271 data downloaded and saved.
# G006 data downloaded and saved.
# I009 data downloaded and saved.
# J892 data downloaded and saved.
# Z124 data downloaded and saved.
# I028 data downloaded and saved.
# G177 data downloaded and saved.
# J366 data downloaded and saved.
# J587 data downloaded and saved.
# CHUA data downloaded and saved.
# DONA data downloaded and saved.
# J038 data downloaded and saved.
# J396 data downloaded and saved.
# Z107 data downloaded and saved.
# J660 data downloaded and saved.
# G104 data downloaded and saved.
# J023 data downloaded and saved.
# J693 data downloaded and saved.
# J047 data downloaded and saved.
# G129 data downloaded and saved.
# G184 data downloaded and saved.
# J011 data downloaded and saved.
# J193 data downloaded and saved.
# J066 data downloaded and saved.
# G070 data downloaded and saved.
# G040 data downloaded and saved.
# CHUL data downloaded and saved.
# J998 data downloaded and saved.
# G014 data downloaded and saved.
# G181 data downloaded and saved.
# J302 data downloaded and saved.
# J455 data downloaded and saved.
# J129 data downloaded and saved.
# G132 data downloaded and saved.
# G023 data downloaded and saved.
# J207 data downloaded and saved.
# G059 data downloaded and saved.
# J685 data downloaded and saved.
# J929 data downloaded and saved.
# J369 data downloaded and saved.
# J053 data downloaded and saved.
# J430 data downloaded and saved.
# J525 data downloaded and saved.
# I020 data downloaded and saved.
# R004 data downloaded and saved.
# J599 data downloaded and saved.
# J217 data downloaded and saved.
# J084 data downloaded and saved.
# MES3 data downloaded and saved.
# SA04 data downloaded and saved.
# G045 data downloaded and saved.
# G002 data downloaded and saved.
# J429 data downloaded and saved.
# J855 data downloaded and saved.
# ILAN data downloaded and saved.
# J715 data downloaded and saved.
# I005 data downloaded and saved.
# J742 data downloaded and saved.
# J020 data downloaded and saved.
# X062 data downloaded and saved.
# G018 data downloaded and saved.
# FLON data downloaded and saved.
# J393 data downloaded and saved.
# H101 data downloaded and saved.
# J328 data downloaded and saved.
# J783 data downloaded and saved.
# J939 data downloaded and saved.
# J280 data downloaded and saved.
# I104 data downloaded and saved.
# J076 data downloaded and saved.
# G214 data downloaded and saved.
# J465 data downloaded and saved.
# Z103 data downloaded and saved.
# J987 data downloaded and saved.
# J067 data downloaded and saved.
# I059 data downloaded and saved.
# J575 data downloaded and saved.
# J166 data downloaded and saved.
# I070 data downloaded and saved.
# G048 data downloaded and saved.
# J267 data downloaded and saved.
# G108 data downloaded and saved.
# HUAN data downloaded and saved.
# J145 data downloaded and saved.
# J727 data downloaded and saved.
# J492 data downloaded and saved.
# J523 data downloaded and saved.
# J832 data downloaded and saved.
# G207 data downloaded and saved.
# J894 data downloaded and saved.
# J588 data downloaded and saved.
# J889 data downloaded and saved.
# J287 data downloaded and saved.
# HOMI data downloaded and saved.
# J348 data downloaded and saved.
# J907 data downloaded and saved.
# J880 data downloaded and saved.
# G120 data downloaded and saved.
# I017 data downloaded and saved.
# J432 data downloaded and saved.
# J490 data downloaded and saved.
# J468 data downloaded and saved.
# J223 data downloaded and saved.
# I094 data downloaded and saved.
# YUSN data downloaded and saved.
# G150 data downloaded and saved.
# Z206 data downloaded and saved.
# X088 data downloaded and saved.
# G081 data downloaded and saved.
# NIPU data downloaded and saved.
# J257 data downloaded and saved.
# J203 data downloaded and saved.
# TEGN data downloaded and saved.
# G141 data downloaded and saved.
# J861 data downloaded and saved.
# ERLN data downloaded and saved.
# X091 data downloaded and saved.
# G185 data downloaded and saved.
# J543 data downloaded and saved.
# TTUN data downloaded and saved.
# J688 data downloaded and saved.
# J905 data downloaded and saved.
# J202 data downloaded and saved.
# J507 data downloaded and saved.
# G011 data downloaded and saved.
# J445 data downloaded and saved.
# J920 data downloaded and saved.
# J009 data downloaded and saved.
# J428 data downloaded and saved.
# S057 data downloaded and saved.
# I025 data downloaded and saved.
# HSUE data downloaded and saved.
# THAI data downloaded and saved.
# J904 data downloaded and saved.
# J043 data downloaded and saved.
# J978 data downloaded and saved.
# J245 data downloaded and saved.
# J797 data downloaded and saved.
# G112 data downloaded and saved.
# Z119 data downloaded and saved.
# J392 data downloaded and saved.
# J126 data downloaded and saved.
# J172 data downloaded and saved.
# J636 data downloaded and saved.
# S064 data downloaded and saved.
# HUA3 data downloaded and saved.
# J239 data downloaded and saved.
# H004 data downloaded and saved.
# J312 data downloaded and saved.
# G196 data downloaded and saved.
# J664 data downloaded and saved.
# TTSH data downloaded and saved.
# PENL data downloaded and saved.
# J296 data downloaded and saved.
# J104 data downloaded and saved.
# J597 data downloaded and saved.
# J195 data downloaded and saved.
# J912 data downloaded and saved.
# OKN1 data downloaded and saved.
# J890 data downloaded and saved.
# G049 data downloaded and saved.
# J458 data downloaded and saved.
# J443 data downloaded and saved.
# J891 data downloaded and saved.
# J497 data downloaded and saved.
# J810 data downloaded and saved.
# J610 data downloaded and saved.
# TUNS data downloaded and saved.
# G041 data downloaded and saved.
# J059 data downloaded and saved.
# G071 data downloaded and saved.
# J158 data downloaded and saved.
# SUN2 data downloaded and saved.
# J629 data downloaded and saved.
# SANI data downloaded and saved.
# J871 data downloaded and saved.
# J830 data downloaded and saved.
# J469 data downloaded and saved.
# I048 data downloaded and saved.
# J553 data downloaded and saved.
# J118 data downloaded and saved.
# J784 data downloaded and saved.
# J090 data downloaded and saved.
# J333 data downloaded and saved.
# I011 data downloaded and saved.
# J386 data downloaded and saved.
# J085 data downloaded and saved.
# J814 data downloaded and saved.
# J628 data downloaded and saved.
# J847 data downloaded and saved.
# J150 data downloaded and saved.
# J516 data downloaded and saved.
# I012 data downloaded and saved.
# J208 data downloaded and saved.
# S065 data downloaded and saved.
# J345 data downloaded and saved.
# J911 data downloaded and saved.
# J956 data downloaded and saved.
# J625 data downloaded and saved.
# G216 data downloaded and saved.
# X082 data downloaded and saved.
# J394 data downloaded and saved.
# Z211 data downloaded and saved.
# J989 data downloaded and saved.
# KNKO data downloaded and saved.
# J759 data downloaded and saved.
# J803 data downloaded and saved.
# J551 data downloaded and saved.
# J298 data downloaded and saved.
# I067 data downloaded and saved.
# YNTS data downloaded and saved.
# G201 data downloaded and saved.
# J320 data downloaded and saved.
# X058 data downloaded and saved.
# J440 data downloaded and saved.
# G019 data downloaded and saved.
# J237 data downloaded and saved.
# Z114 data downloaded and saved.
# I019 data downloaded and saved.
# G190 data downloaded and saved.
# J843 data downloaded and saved.
# HUAP data downloaded and saved.
# J711 data downloaded and saved.
# J370 data downloaded and saved.
# J579 data downloaded and saved.
# J107 data downloaded and saved.
# R007 data downloaded and saved.
# J289 data downloaded and saved.
# J243 data downloaded and saved.
# CHI0 data downloaded and saved.
# G107 data downloaded and saved.
# J069 data downloaded and saved.
# MIN3 data downloaded and saved.
# G126 data downloaded and saved.
# J358 data downloaded and saved.
# S007 data downloaded and saved.
# J408 data downloaded and saved.
# J515 data downloaded and saved.
# J109 data downloaded and saved.
# G157 data downloaded and saved.
# J983 data downloaded and saved.
# CHUK data downloaded and saved.
# H103 data downloaded and saved.
# J776 data downloaded and saved.
# J375 data downloaded and saved.
# J592 data downloaded and saved.
# J422 data downloaded and saved.
# I008 data downloaded and saved.
# X076 data downloaded and saved.
# G052 data downloaded and saved.
# G035 data downloaded and saved.
# G080 data downloaded and saved.
# J314 data downloaded and saved.
# J027 data downloaded and saved.
# J876 data downloaded and saved.
# J734 data downloaded and saved.
# J578 data downloaded and saved.
# J779 data downloaded and saved.
# G199 data downloaded and saved.
# J163 data downloaded and saved.
# J153 data downloaded and saved.
# J233 data downloaded and saved.
# J874 data downloaded and saved.
# SFON data downloaded and saved.
# G220 data downloaded and saved.
# HSIN data downloaded and saved.
# S067 data downloaded and saved.
# J042 data downloaded and saved.
# GUKN data downloaded and saved.
# G013 data downloaded and saved.
# I037 data downloaded and saved.
# I050 data downloaded and saved.
# J526 data downloaded and saved.
# G007 data downloaded and saved.
# J823 data downloaded and saved.
# J281 data downloaded and saved.
# J180 data downloaded and saved.
# J021 data downloaded and saved.
# J538 data downloaded and saved.
# J407 data downloaded and saved.
# J658 data downloaded and saved.
# J484 data downloaded and saved.
# J574 data downloaded and saved.
# Z108 data downloaded and saved.
# G162 data downloaded and saved.
# S069 data downloaded and saved.
# J817 data downloaded and saved.
# J351 data downloaded and saved.
# J577 data downloaded and saved.
# G168 data downloaded and saved.
# DOKD data downloaded and saved.
# G068 data downloaded and saved.
# BHAO data downloaded and saved.
# J122 data downloaded and saved.
# Z117 data downloaded and saved.
# J062 data downloaded and saved.
# J852 data downloaded and saved.
# G103 data downloaded and saved.
# TSKB data downloaded and saved.
# J563 data downloaded and saved.
# G172 data downloaded and saved.
# J390 data downloaded and saved.
# J206 data downloaded and saved.
# G163 data downloaded and saved.
# J012 data downloaded and saved.
# X087 data downloaded and saved.
# J050 data downloaded and saved.
# J070 data downloaded and saved.
# STA9 data downloaded and saved.
# J343 data downloaded and saved.
# J657 data downloaded and saved.
# J277 data downloaded and saved.
# J620 data downloaded and saved.
# J174 data downloaded and saved.
# S049 data downloaded and saved.
# J371 data downloaded and saved.
# J951 data downloaded and saved.
# J679 data downloaded and saved.
# J300 data downloaded and saved.
# ALIS data downloaded and saved.
# J882 data downloaded and saved.
# J656 data downloaded and saved.
# J781 data downloaded and saved.
# J471 data downloaded and saved.
# JSUI data downloaded and saved.
# G198 data downloaded and saved.
# J176 data downloaded and saved.
# HUYS data downloaded and saved.
# G037 data downloaded and saved.
# Z116 data downloaded and saved.
# J744 data downloaded and saved.
# J511 data downloaded and saved.
# J924 data downloaded and saved.
# J566 data downloaded and saved.
# J116 data downloaded and saved.
# J763 data downloaded and saved.
# Z112 data downloaded and saved.
# J286 data downloaded and saved.
# J762 data downloaded and saved.
# X072 data downloaded and saved.
# G047 data downloaded and saved.
# J004 data downloaded and saved.
# J536 data downloaded and saved.
# Z212 data downloaded and saved.
# J909 data downloaded and saved.
# SJPU data downloaded and saved.
# J845 data downloaded and saved.
# J531 data downloaded and saved.
# YULI data downloaded and saved.
# J162 data downloaded and saved.
# G118 data downloaded and saved.
# J856 data downloaded and saved.
# J368 data downloaded and saved.
# I076 data downloaded and saved.
# G170 data downloaded and saved.
# J496 data downloaded and saved.
# J893 data downloaded and saved.
# J481 data downloaded and saved.
# HRGN data downloaded and saved.
# J750 data downloaded and saved.
# J346 data downloaded and saved.
# G133 data downloaded and saved.
# J853 data downloaded and saved.
# I041 data downloaded and saved.
# J568 data downloaded and saved.
# J149 data downloaded and saved.
# X083 data downloaded and saved.
# S053 data downloaded and saved.
# J227 data downloaded and saved.
# J670 data downloaded and saved.
# G197 data downloaded and saved.
# J096 data downloaded and saved.
# J367 data downloaded and saved.
# J514 data downloaded and saved.
# G146 data downloaded and saved.
# SUAO data downloaded and saved.
# J709 data downloaded and saved.
# J275 data downloaded and saved.
# S170 data downloaded and saved.
# G029 data downloaded and saved.
# G164 data downloaded and saved.
# J676 data downloaded and saved.
# G064 data downloaded and saved.
# J329 data downloaded and saved.
# J500 data downloaded and saved.
# G102 data downloaded and saved.
# J722 data downloaded and saved.
# J103 data downloaded and saved.
# J091 data downloaded and saved.
# I090 data downloaded and saved.
# J228 data downloaded and saved.
# G149 data downloaded and saved.
# G222 data downloaded and saved.
# JPIN data downloaded and saved.
# J402 data downloaded and saved.
# G090 data downloaded and saved.
# J003 data downloaded and saved.
# I052 data downloaded and saved.
# S23R data downloaded and saved.
# J288 data downloaded and saved.
# I051 data downloaded and saved.
# J743 data downloaded and saved.
# J151 data downloaded and saved.
# J143 data downloaded and saved.
# G137 data downloaded and saved.
# J480 data downloaded and saved.
# J769 data downloaded and saved.
# J697 data downloaded and saved.
# TSHI data downloaded and saved.
# J199 data downloaded and saved.
# I053 data downloaded and saved.
# G095 data downloaded and saved.
# WOL5 data downloaded and saved.
# J672 data downloaded and saved.
# G224 data downloaded and saved.
# J098 data downloaded and saved.
# G227 data downloaded and saved.
# J190 data downloaded and saved.
# G158 data downloaded and saved.
# G085 data downloaded and saved.
# J437 data downloaded and saved.
# J089 data downloaded and saved.
# BIMO data downloaded and saved.
# HOPN data downloaded and saved.
# J501 data downloaded and saved.
# J864 data downloaded and saved.
# J353 data downloaded and saved.
# I088 data downloaded and saved.
# H023 data downloaded and saved.
# J701 data downloaded and saved.
# J425 data downloaded and saved.
# J534 data downloaded and saved.
# J986 data downloaded and saved.
# Z207 data downloaded and saved.
# J935 data downloaded and saved.
# J246 data downloaded and saved.
# J452 data downloaded and saved.
# PNSI data downloaded and saved.
# J477 data downloaded and saved.
# J794 data downloaded and saved.
# J212 data downloaded and saved.
# G069 data downloaded and saved.
# J612 data downloaded and saved.
# J885 data downloaded and saved.
# CHNN data downloaded and saved.
# J499 data downloaded and saved.
# J234 data downloaded and saved.
# G159 data downloaded and saved.
# J530 data downloaded and saved.
# S059 data downloaded and saved.
# J896 data downloaded and saved.
# J590 data downloaded and saved.
# DAHU data downloaded and saved.
# G182 data downloaded and saved.
# J110 data downloaded and saved.
# G187 data downloaded and saved.
# J648 data downloaded and saved.
# J917 data downloaded and saved.
# J626 data downloaded and saved.
# I063 data downloaded and saved.
# J230 data downloaded and saved.
# NDH2 data downloaded and saved.
# JUNA data downloaded and saved.
# J344 data downloaded and saved.
# J218 data downloaded and saved.
# J255 data downloaded and saved.
# X085 data downloaded and saved.
# J945 data downloaded and saved.
# W029 data downloaded and saved.
# G063 data downloaded and saved.
# J001 data downloaded and saved.
# G213 data downloaded and saved.
# J503 data downloaded and saved.
# J996 data downloaded and saved.
# NM0D data downloaded and saved.
# J888 data downloaded and saved.
# DAJN data downloaded and saved.
# J415 data downloaded and saved.
# H010 data downloaded and saved.
# G147 data downloaded and saved.
# J467 data downloaded and saved.
# J602 data downloaded and saved.
# TUNH data downloaded and saved.
# J359 data downloaded and saved.
# G156 data downloaded and saved.
# J357 data downloaded and saved.
# GUK2 data downloaded and saved.
# J510 data downloaded and saved.
# TSK2 data downloaded and saved.
# G123 data downloaded and saved.
# PEPU data downloaded and saved.
# J840 data downloaded and saved.
# STK2 data downloaded and saved.
# J793 data downloaded and saved.
# J365 data downloaded and saved.
# Z208 data downloaded and saved.
# J680 data downloaded and saved.
# G012 data downloaded and saved.
# J196 data downloaded and saved.
# J606 data downloaded and saved.
# I098 data downloaded and saved.
# Z111 data downloaded and saved.
# G056 data downloaded and saved.
# J645 data downloaded and saved.
# J804 data downloaded and saved.
# J638 data downloaded and saved.
# J018 data downloaded and saved.
# G075 data downloaded and saved.
# J278 data downloaded and saved.
# J451 data downloaded and saved.
# J603 data downloaded and saved.
# J906 data downloaded and saved.
# G217 data downloaded and saved.
# J249 data downloaded and saved.
# J979 data downloaded and saved.
# J354 data downloaded and saved.
# PAKU data downloaded and saved.
# J562 data downloaded and saved.
# J782 data downloaded and saved.
# J504 data downloaded and saved.
# J542 data downloaded and saved.
# Z204 data downloaded and saved.
# PINT data downloaded and saved.
# J720 data downloaded and saved.
# GMSD data downloaded and saved.
# J541 data downloaded and saved.
# KSMV data downloaded and saved.
# X060 data downloaded and saved.
# J730 data downloaded and saved.
# LANB data downloaded and saved.
# I038 data downloaded and saved.
# J729 data downloaded and saved.
# I022 data downloaded and saved.
# J350 data downloaded and saved.
# H016 data downloaded and saved.
# J439 data downloaded and saved.
# G062 data downloaded and saved.
# J209 data downloaded and saved.
# J992 data downloaded and saved.
# J413 data downloaded and saved.
# J135 data downloaded and saved.
# TKSC data downloaded and saved.
# J881 data downloaded and saved.
# S105 data downloaded and saved.
# J560 data downloaded and saved.
# J815 data downloaded and saved.
# LSAN data downloaded and saved.
# G053 data downloaded and saved.
# I058 data downloaded and saved.
# J080 data downloaded and saved.
# J582 data downloaded and saved.
# J322 data downloaded and saved.
# J694 data downloaded and saved.
# J169 data downloaded and saved.
# J506 data downloaded and saved.
# J410 data downloaded and saved.
# J754 data downloaded and saved.
# J624 data downloaded and saved.
# J936 data downloaded and saved.
# HLIU data downloaded and saved.
# J765 data downloaded and saved.
# R015 data downloaded and saved.
# J030 data downloaded and saved.
# G188 data downloaded and saved.
# TAPO data downloaded and saved.
# J015 data downloaded and saved.
# J463 data downloaded and saved.
# J919 data downloaded and saved.
# J663 data downloaded and saved.
# TNML data downloaded and saved.
# J071 data downloaded and saved.
# Z105 data downloaded and saved.
# J705 data downloaded and saved.
# J652 data downloaded and saved.
# J378 data downloaded and saved.
# J528 data downloaded and saved.
# X075 data downloaded and saved.
# Z203 data downloaded and saved.
# G130 data downloaded and saved.
# J799 data downloaded and saved.
# G038 data downloaded and saved.
# J064 data downloaded and saved.
# J863 data downloaded and saved.
# J347 data downloaded and saved.
# J309 data downloaded and saved.
# S106 data downloaded and saved.
# J101 data downloaded and saved.
# J937 data downloaded and saved.
# J926 data downloaded and saved.
# J240 data downloaded and saved.
# J167 data downloaded and saved.
# S050 data downloaded and saved.
# WAN2 data downloaded and saved.
# J662 data downloaded and saved.
# J755 data downloaded and saved.
# J482 data downloaded and saved.
# G016 data downloaded and saved.
# Z120 data downloaded and saved.
# J441 data downloaded and saved.
# J411 data downloaded and saved.
# X049 data downloaded and saved.
# TAT3 data downloaded and saved.
# SANZ data downloaded and saved.
# J321 data downloaded and saved.
# I013 data downloaded and saved.
# PL00 data downloaded and saved.
# R019 data downloaded and saved.
# ISHI data downloaded and saved.
# NOK2 data downloaded and saved.
# J591 data downloaded and saved.
# J157 data downloaded and saved.
# ERPN data downloaded and saved.
# J529 data downloaded and saved.
# I060 data downloaded and saved.
# PEIN data downloaded and saved.
# J673 data downloaded and saved.
# J554 data downloaded and saved.
# I035 data downloaded and saved.
# J154 data downloaded and saved.
# J934 data downloaded and saved.
# X074 data downloaded and saved.
# J666 data downloaded and saved.
# KASU data downloaded and saved.
# J668 data downloaded and saved.
# KZN1 data downloaded and saved.
# J677 data downloaded and saved.
# J790 data downloaded and saved.
# G050 data downloaded and saved.
# J552 data downloaded and saved.
# J600 data downloaded and saved.
# CHI7 data downloaded and saved.
# I016 data downloaded and saved.
# KNYA data downloaded and saved.
# I057 data downloaded and saved.
# J549 data downloaded and saved.
# J134 data downloaded and saved.
# J775 data downloaded and saved.
# I072 data downloaded and saved.
# PIN9 data downloaded and saved.
# J777 data downloaded and saved.
# I034 data downloaded and saved.
# J796 data downloaded and saved.
# Z110 data downloaded and saved.
# G091 data downloaded and saved.
# J867 data downloaded and saved.
# J969 data downloaded and saved.
# J899 data downloaded and saved.
# R014 data downloaded and saved.
# J381 data downloaded and saved.
# J955 data downloaded and saved.
# J035 data downloaded and saved.
# J214 data downloaded and saved.
# J547 data downloaded and saved.
# J595 data downloaded and saved.
# J714 data downloaded and saved.
# J908 data downloaded and saved.
# J713 data downloaded and saved.
# J256 data downloaded and saved.
# J571 data downloaded and saved.
# R006 data downloaded and saved.
# J834 data downloaded and saved.
# J902 data downloaded and saved.
# S055 data downloaded and saved.
# J024 data downloaded and saved.
# J449 data downloaded and saved.
# J971 data downloaded and saved.
# J002 data downloaded and saved.
# J194 data downloaded and saved.
# G119 data downloaded and saved.
# J975 data downloaded and saved.
# J363 data downloaded and saved.
# J827 data downloaded and saved.
# H007 data downloaded and saved.
# J573 data downloaded and saved.
# H102 data downloaded and saved.
# SEOI data downloaded and saved.
# J780 data downloaded and saved.
# S006 data downloaded and saved.
# S043 data downloaded and saved.
# WANS data downloaded and saved.
# GOJE data downloaded and saved.
# WIPN data downloaded and saved.
# I042 data downloaded and saved.
# G020 data downloaded and saved.
# I113 data downloaded and saved.
# J041 data downloaded and saved.
# J737 data downloaded and saved.
# J456 data downloaded and saved.
# JPEI data downloaded and saved.
# J854 data downloaded and saved.
# X070 data downloaded and saved.
# J248 data downloaded and saved.
# J306 data downloaded and saved.
# Z118 data downloaded and saved.
# J112 data downloaded and saved.
# J631 data downloaded and saved.
# G051 data downloaded and saved.
# J414 data downloaded and saved.
# YM05 data downloaded and saved.
# J872 data downloaded and saved.
# J746 data downloaded and saved.
# J773 data downloaded and saved.
# J962 data downloaded and saved.
# J698 data downloaded and saved.
# J703 data downloaded and saved.
# J263 data downloaded and saved.
# KUAN data downloaded and saved.
# J232 data downloaded and saved.
# NDH3 data downloaded and saved.
# MIZT data downloaded and saved.
# S047 data downloaded and saved.
# CHTS data downloaded and saved.
# J820 data downloaded and saved.
# G000 data downloaded and saved.
# J412 data downloaded and saved.
# J619 data downloaded and saved.
# J224 data downloaded and saved.
# J752 data downloaded and saved.
# J225 data downloaded and saved.
# DNDA data downloaded and saved.
# G202 data downloaded and saved.
# J580 data downloaded and saved.
# J268 data downloaded and saved.
# G092 data downloaded and saved.
# J977 data downloaded and saved.
# J739 data downloaded and saved.
# J903 data downloaded and saved.
# J026 data downloaded and saved.
# J221 data downloaded and saved.
# J741 data downloaded and saved.
# Z205 data downloaded and saved.
# I015 data downloaded and saved.
# J995 data downloaded and saved.
# J318 data downloaded and saved.
# J175 data downloaded and saved.
# J088 data downloaded and saved.
# J383 data downloaded and saved.
# I077 data downloaded and saved.
# I081 data downloaded and saved.
# LANY data downloaded and saved.
# J160 data downloaded and saved.
# J879 data downloaded and saved.
# G009 data downloaded and saved.
# G160 data downloaded and saved.
# W030 data downloaded and saved.
# J991 data downloaded and saved.
# J144 data downloaded and saved.
# G033 data downloaded and saved.
# FKD2 data downloaded and saved.
# G143 data downloaded and saved.
# DSIN data downloaded and saved.
# BANC data downloaded and saved.
# J036 data downloaded and saved.
# J946 data downloaded and saved.
# I031 data downloaded and saved.
# J231 data downloaded and saved.
# J686 data downloaded and saved.
# J269 data downloaded and saved.
# KGNI data downloaded and saved.
# J170 data downloaded and saved.
# J684 data downloaded and saved.
# J700 data downloaded and saved.
# J886 data downloaded and saved.
# J826 data downloaded and saved.
# TAPE data downloaded and saved.
# J133 data downloaded and saved.
# J646 data downloaded and saved.
# G206 data downloaded and saved.
# J938 data downloaded and saved.
# J177 data downloaded and saved.
# J559 data downloaded and saved.
# J941 data downloaded and saved.
# G212 data downloaded and saved.
# I044 data downloaded and saved.
# J379 data downloaded and saved.
# J509 data downloaded and saved.
# J642 data downloaded and saved.
# HNSN data downloaded and saved.
# J740 data downloaded and saved.
# WLIP data downloaded and saved.
# G194 data downloaded and saved.
# J957 data downloaded and saved.
# I099 data downloaded and saved.
# J653 data downloaded and saved.
# J994 data downloaded and saved.
# J448 data downloaded and saved.
# J738 data downloaded and saved.
# J399 data downloaded and saved.
# J487 data downloaded and saved.
# J948 data downloaded and saved.
# J825 data downloaded and saved.
# J017 data downloaded and saved.
# J721 data downloaded and saved.
# G074 data downloaded and saved.
# J564 data downloaded and saved.
# J057 data downloaded and saved.
# G003 data downloaded and saved.
# J216 data downloaded and saved.
# J389 data downloaded and saved.
# J805 data downloaded and saved.
# SANL data downloaded and saved.
# J334 data downloaded and saved.
# J596 data downloaded and saved.
# G094 data downloaded and saved.
# J522 data downloaded and saved.
# G125 data downloaded and saved.
# G204 data downloaded and saved.
# Z123 data downloaded and saved.
# J630 data downloaded and saved.
# I033 data downloaded and saved.
# J283 data downloaded and saved.
# I021 data downloaded and saved.
# J083 data downloaded and saved.
# J848 data downloaded and saved.
# J261 data downloaded and saved.
# I006 data downloaded and saved.
# MZSW data downloaded and saved.
# G114 data downloaded and saved.
# J362 data downloaded and saved.
# J608 data downloaded and saved.
# G173 data downloaded and saved.
# J928 data downloaded and saved.
# J247 data downloaded and saved.
# G192 data downloaded and saved.
# G218 data downloaded and saved.
# G219 data downloaded and saved.
# J546 data downloaded and saved.
# X084 data downloaded and saved.
# PAO2 data downloaded and saved.
# J802 data downloaded and saved.
# J604 data downloaded and saved.
# G099 data downloaded and saved.
# J006 data downloaded and saved.
# DNAN data downloaded and saved.
# TEN3 data downloaded and saved.
# J527 data downloaded and saved.
# J213 data downloaded and saved.
# G046 data downloaded and saved.
# I073 data downloaded and saved.
# J897 data downloaded and saved.
# BLOW data downloaded and saved.
# J675 data downloaded and saved.
# G065 data downloaded and saved.
# J674 data downloaded and saved.
# J691 data downloaded and saved.
# LNKO data downloaded and saved.
# J475 data downloaded and saved.
# J712 data downloaded and saved.
# J751 data downloaded and saved.
# J127 data downloaded and saved.
# J184 data downloaded and saved.
# J942 data downloaded and saved.
# G042 data downloaded and saved.
# J380 data downloaded and saved.
# TSL1 data downloaded and saved.
# J250 data downloaded and saved.
# J747 data downloaded and saved.
# G022 data downloaded and saved.
# J388 data downloaded and saved.
# J875 data downloaded and saved.
# G151 data downloaded and saved.
# S110 data downloaded and saved.
# J725 data downloaded and saved.
# J607 data downloaded and saved.
# J706 data downloaded and saved.
# G145 data downloaded and saved.
# G004 data downloaded and saved.
# G195 data downloaded and saved.
# I061 data downloaded and saved.
# TSIO data downloaded and saved.
# J605 data downloaded and saved.
# SHLU data downloaded and saved.
# YENL data downloaded and saved.
# LIKN data downloaded and saved.
# J851 data downloaded and saved.
# G111 data downloaded and saved.
# YLSS data downloaded and saved.
# J710 data downloaded and saved.
# G087 data downloaded and saved.
# H025 data downloaded and saved.
# S066 data downloaded and saved.
# G039 data downloaded and saved.
# J778 data downloaded and saved.
# J766 data downloaded and saved.
# J161 data downloaded and saved.
# Z201 data downloaded and saved.
# J454 data downloaded and saved.
# DNFU data downloaded and saved.
# J293 data downloaded and saved.
# J215 data downloaded and saved.
# C001 data downloaded and saved.
# J593 data downloaded and saved.
# J259 data downloaded and saved.
# J557 data downloaded and saved.
# J081 data downloaded and saved.
# J649 data downloaded and saved.
# J976 data downloaded and saved.
# J859 data downloaded and saved.
# J621 data downloaded and saved.
# I030 data downloaded and saved.
# J927 data downloaded and saved.
# WUKU data downloaded and saved.
# FKDO data downloaded and saved.
# J717 data downloaded and saved.
# S054 data downloaded and saved.
# SNDI data downloaded and saved.
# J435 data downloaded and saved.
# J387 data downloaded and saved.
# J707 data downloaded and saved.
# J113 data downloaded and saved.
# G024 data downloaded and saved.
# J282 data downloaded and saved.
# J438 data downloaded and saved.
# J152 data downloaded and saved.
# J931 data downloaded and saved.
# J028 data downloaded and saved.
# J828 data downloaded and saved.
# J114 data downloaded and saved.
# BAL6 data downloaded and saved.
# J097 data downloaded and saved.
# J940 data downloaded and saved.
# J669 data downloaded and saved.
# Z106 data downloaded and saved.
# I027 data downloaded and saved.
# J748 data downloaded and saved.
# J768 data downloaded and saved.
# J391 data downloaded and saved.
# J488 data downloaded and saved.
# J968 data downloaded and saved.
# J633 data downloaded and saved.
# R003 data downloaded and saved.
# G078 data downloaded and saved.
# I091 data downloaded and saved.
# G055 data downloaded and saved.
# PUS2 data downloaded and saved.
# NKO2 data downloaded and saved.
# G180 data downloaded and saved.
# G073 data downloaded and saved.
# G225 data downloaded and saved.
# I024 data downloaded and saved.
# I068 data downloaded and saved.
# J984 data downloaded and saved.
# TUNM data downloaded and saved.
# J356 data downloaded and saved.
# J450 data downloaded and saved.
# J323 data downloaded and saved.
# J060 data downloaded and saved.
# J910 data downloaded and saved.
# J659 data downloaded and saved.
# J197 data downloaded and saved.
# CHE8 data downloaded and saved.
# SANY data downloaded and saved.
# J115 data downloaded and saved.
# J736 data downloaded and saved.
# KGN0 data downloaded and saved.
# G127 data downloaded and saved.
# J844 data downloaded and saved.
# J873 data downloaded and saved.
# J337 data downloaded and saved.
# TLT3 data downloaded and saved.
# YUL1 data downloaded and saved.
# I014 data downloaded and saved.
# J944 data downloaded and saved.
# J459 data downloaded and saved.
# S052 data downloaded and saved.
# J883 data downloaded and saved.
# J622 data downloaded and saved.
# J585 data downloaded and saved.
# J082 data downloaded and saved.
# I075 data downloaded and saved.
# J434 data downloaded and saved.
# I093 data downloaded and saved.
# J565 data downloaded and saved.
# J472 data downloaded and saved.
# J932 data downloaded and saved.
# J519 data downloaded and saved.
# LOY1 data downloaded and saved.
# J858 data downloaded and saved.
# J007 data downloaded and saved.
# J639 data downloaded and saved.
# NDH1 data downloaded and saved.
# J644 data downloaded and saved.
# J173 data downloaded and saved.
# J310 data downloaded and saved.
# TMAL data downloaded and saved.
# J031 data downloaded and saved.
# J614 data downloaded and saved.
# J594 data downloaded and saved.
# CHOF data downloaded and saved.
# MIAO data downloaded and saved.
# J470 data downloaded and saved.
# J297 data downloaded and saved.
# J326 data downloaded and saved.
# J822 data downloaded and saved.
# Z109 data downloaded and saved.
# Z121 data downloaded and saved.
# LTUN data downloaded and saved.
# G179 data downloaded and saved.
# SJ51 data downloaded and saved.
# Z101 data downloaded and saved.
# J866 data downloaded and saved.
# FUDN data downloaded and saved.
# G116 data downloaded and saved.
# SHUL data downloaded and saved.
# G128 data downloaded and saved.
# J841 data downloaded and saved.
# J806 data downloaded and saved.
# I055 data downloaded and saved.
# J265 data downloaded and saved.
# J179 data downloaded and saved.
# J095 data downloaded and saved.
# J993 data downloaded and saved.
# J086 data downloaded and saved.
# J733 data downloaded and saved.
# J238 data downloaded and saved.
# CWEN data downloaded and saved.
# J753 data downloaded and saved.
# G100 data downloaded and saved.
# G171 data downloaded and saved.
# J037 data downloaded and saved.
# G154 data downloaded and saved.
# J181 data downloaded and saved.
# J632 data downloaded and saved.
# S107 data downloaded and saved.
# G086 data downloaded and saved.
# GAIS data downloaded and saved.
# J785 data downloaded and saved.
# J548 data downloaded and saved.
# PAO1 data downloaded and saved.
# G124 data downloaded and saved.
# J189 data downloaded and saved.
# J539 data downloaded and saved.
# S062 data downloaded and saved.
# USUD data downloaded and saved.
# J125 data downloaded and saved.
# J964 data downloaded and saved.
# J473 data downloaded and saved.
# LONT data downloaded and saved.
# AIRA data downloaded and saved.
# MTKB data downloaded and saved.
# J364 data downloaded and saved.
# TKBA data downloaded and saved.
# J178 data downloaded and saved.
# J923 data downloaded and saved.
# J491 data downloaded and saved.
# TEGS data downloaded and saved.
# J130 data downloaded and saved.
# J813 data downloaded and saved.
# J423 data downloaded and saved.
# TAN2 data downloaded and saved.
# J106 data downloaded and saved.
# G032 data downloaded and saved.
# CHUN data downloaded and saved.
# J997 data downloaded and saved.
# I046 data downloaded and saved.
# G205 data downloaded and saved.
# G153 data downloaded and saved.
# J444 data downloaded and saved.
# G025 data downloaded and saved.
# J279 data downloaded and saved.
# G193 data downloaded and saved.
# J849 data downloaded and saved.
# CHI4 data downloaded and saved.
# J665 data downloaded and saved.
# G054 data downloaded and saved.
# SLI1 data downloaded and saved.
# J637 data downloaded and saved.
# G082 data downloaded and saved.
# TAPU data downloaded and saved.
# J870 data downloaded and saved.
# FENP data downloaded and saved.
# G178 data downloaded and saved.
# Z113 data downloaded and saved.
# S046 data downloaded and saved.
# J618 data downloaded and saved.
# J836 data downloaded and saved.
# X063 data downloaded and saved.
# G076 data downloaded and saved.
# J276 data downloaded and saved.
# ANKN data downloaded and saved.
# J791 data downloaded and saved.
# I092 data downloaded and saved.
# J079 data downloaded and saved.
# J533 data downloaded and saved.
# J049 data downloaded and saved.
# J242 data downloaded and saved.
# J716 data downloaded and saved.
# J460 data downloaded and saved.
# JCH2 data downloaded and saved.
# G109 data downloaded and saved.
# S101 data downloaded and saved.
# G122 data downloaded and saved.
# WANC data downloaded and saved.
# J949 data downloaded and saved.
# J774 data downloaded and saved.
# T118 data downloaded and saved.
# J884 data downloaded and saved.
# J191 data downloaded and saved.
# J999 data downloaded and saved.
# J650 data downloaded and saved.
# J332 data downloaded and saved.
# TLT1 data downloaded and saved.
# S104 data downloaded and saved.
# I085 data downloaded and saved.
# I043 data downloaded and saved.
# SHA1 data downloaded and saved.
# J678 data downloaded and saved.
# G088 data downloaded and saved.
# J316 data downloaded and saved.
# J586 data downloaded and saved.
# J540 data downloaded and saved.
# J476 data downloaded and saved.
# SMST data downloaded and saved.
# J260 data downloaded and saved.
# J291 data downloaded and saved.
# J687 data downloaded and saved.
# J204 data downloaded and saved.
# DCHU data downloaded and saved.
# J307 data downloaded and saved.
# J266 data downloaded and saved.
# J690 data downloaded and saved.
# J315 data downloaded and saved.
# J544 data downloaded and saved.
# J970 data downloaded and saved.
# J967 data downloaded and saved.
# J331 data downloaded and saved.
# G221 data downloaded and saved.
# J229 data downloaded and saved.
# PL01 data downloaded and saved.
# G027 data downloaded and saved.
# J486 data downloaded and saved.
# CCJM data downloaded and saved.
# X059 data downloaded and saved.
# J272 data downloaded and saved.
# J045 data downloaded and saved.
# J132 data downloaded and saved.
# G135 data downloaded and saved.
# SUC2 data downloaded and saved.
# J732 data downloaded and saved.
# J305 data downloaded and saved.
# X089 data downloaded and saved.
# J121 data downloaded and saved.
# J838 data downloaded and saved.
# J372 data downloaded and saved.
# J914 data downloaded and saved.
# J433 data downloaded and saved.
# J616 data downloaded and saved.
# J850 data downloaded and saved.
# J131 data downloaded and saved.
# J054 data downloaded and saved.
# J251 data downloaded and saved.
# J512 data downloaded and saved.
# WUFN data downloaded and saved.
# J835 data downloaded and saved.
# G030 data downloaded and saved.
# LSB0 data downloaded and saved.
# J865 data downloaded and saved.
# J788 data downloaded and saved.
# J862 data downloaded and saved.
# S016 data downloaded and saved.
# J724 data downloaded and saved.
# J493 data downloaded and saved.
# G077 data downloaded and saved.
# J965 data downloaded and saved.
# W021 data downloaded and saved.
# J792 data downloaded and saved.
# G079 data downloaded and saved.
# J099 data downloaded and saved.
# FUSN data downloaded and saved.
# J635 data downloaded and saved.
# J253 data downloaded and saved.
# ...
# J204 subdata around main shock 576 saved.
# J205 subdata around main shock 576 saved.
# J206 subdata around main shock 576 saved.
# J207 subdata around main shock 576 saved.
# J209 subdata around main shock 576 saved.
# J210 subdata around main shock 576 saved.
# J211 subdata around main shock 576 saved.
# J212 subdata around main shock 576 saved.
# J213 subdata around main shock 576 saved.
# J214 subdata around main shock 576 saved.
# J215 subdata around main shock 576 saved.
# J216 subdata around main shock 576 saved.
# J217 subdata around main shock 576 saved.
# J218 subdata around main shock 576 saved.
# J219 subdata around main shock 576 saved.
# J220 subdata around main shock 576 saved.
# J222 subdata around main shock 576 saved.
# J223 subdata around main shock 576 saved.
# J224 subdata around main shock 576 saved.
# J225 subdata around main shock 576 saved.
# J226 subdata around main shock 576 saved.
# J228 subdata around main shock 576 saved.
# J231 subdata around main shock 576 saved.
# J232 subdata around main shock 576 saved.
# J233 subdata around main shock 576 saved.
# J235 subdata around main shock 576 saved.
# J236 subdata around main shock 576 saved.
# J237 subdata around main shock 576 saved.
# J238 subdata around main shock 576 saved.
# J239 subdata around main shock 576 saved.
# J240 subdata around main shock 576 saved.
# J241 subdata around main shock 576 saved.
# J242 subdata around main shock 576 saved.
# J244 subdata around main shock 576 saved.
# J246 subdata around main shock 576 saved.
# J543 subdata around main shock 576 saved.
# J544 subdata around main shock 576 saved.
# J547 subdata around main shock 576 saved.
# J549 subdata around main shock 576 saved.
# J550 subdata around main shock 576 saved.
# J551 subdata around main shock 576 saved.
# J552 subdata around main shock 576 saved.
# J553 subdata around main shock 576 saved.
# J554 subdata around main shock 576 saved.
# J555 subdata around main shock 576 saved.
# J556 subdata around main shock 576 saved.
# J557 subdata around main shock 576 saved.
# J559 subdata around main shock 576 saved.
# J560 subdata around main shock 576 saved.
# J561 subdata around main shock 576 saved.
# J563 subdata around main shock 576 saved.
# J564 subdata around main shock 576 saved.
# J565 subdata around main shock 576 saved.
# J566 subdata around main shock 576 saved.
# J567 subdata around main shock 576 saved.
# J568 subdata around main shock 576 saved.
# J571 subdata around main shock 576 saved.
# J581 subdata around main shock 576 saved.
# J582 subdata around main shock 576 saved.
# J583 subdata around main shock 576 saved.
# J584 subdata around main shock 576 saved.
# J585 subdata around main shock 576 saved.
# J586 subdata around main shock 576 saved.
# J587 subdata around main shock 576 saved.
# J588 subdata around main shock 576 saved.
# J589 subdata around main shock 576 saved.
# J590 subdata around main shock 576 saved.
# J591 subdata around main shock 576 saved.
# J592 subdata around main shock 576 saved.
# J593 subdata around main shock 576 saved.
# J627 subdata around main shock 576 saved.
# J752 subdata around main shock 576 saved.
# J753 subdata around main shock 576 saved.
# J754 subdata around main shock 576 saved.
# J755 subdata around main shock 576 saved.
# J795 subdata around main shock 576 saved.
# J796 subdata around main shock 576 saved.
# J797 subdata around main shock 576 saved.
# J798 subdata around main shock 576 saved.
# J799 subdata around main shock 576 saved.
# J800 subdata around main shock 576 saved.
# J801 subdata around main shock 576 saved.
# J802 subdata around main shock 576 saved.
# J803 subdata around main shock 576 saved.
# J806 subdata around main shock 576 saved.
# J807 subdata around main shock 576 saved.
# J810 subdata around main shock 576 saved.
# J845 subdata around main shock 576 saved.
# J903 subdata around main shock 576 saved.
# J904 subdata around main shock 576 saved.
# J905 subdata around main shock 576 saved.
# J907 subdata around main shock 576 saved.
# J908 subdata around main shock 576 saved.
# J909 subdata around main shock 576 saved.
# J910 subdata around main shock 576 saved.
# J911 subdata around main shock 576 saved.
# J912 subdata around main shock 576 saved.
# J913 subdata around main shock 576 saved.
# J914 subdata around main shock 576 saved.
# J915 subdata around main shock 576 saved.
# J916 subdata around main shock 576 saved.
# J917 subdata around main shock 576 saved.
# J918 subdata around main shock 576 saved.
# J920 subdata around main shock 576 saved.
# J922 subdata around main shock 576 saved.
# J924 subdata around main shock 576 saved.
# J925 subdata around main shock 576 saved.
# J926 subdata around main shock 576 saved.
# J928 subdata around main shock 576 saved.
# J929 subdata around main shock 576 saved.
# J930 subdata around main shock 576 saved.
# J931 subdata around main shock 576 saved.
# J932 subdata around main shock 576 saved.
# J933 subdata around main shock 576 saved.
# J934 subdata around main shock 576 saved.
# J935 subdata around main shock 576 saved.
# J936 subdata around main shock 576 saved.
# J937 subdata around main shock 576 saved.
# J938 subdata around main shock 576 saved.
# J939 subdata around main shock 576 saved.
# J940 subdata around main shock 576 saved.
# J941 subdata around main shock 576 saved.
# J942 subdata around main shock 576 saved.
# J943 subdata around main shock 576 saved.
# J944 subdata around main shock 576 saved.
# J945 subdata around main shock 576 saved.
# J946 subdata around main shock 576 saved.
# J947 subdata around main shock 576 saved.
# J948 subdata around main shock 576 saved.
# J949 subdata around main shock 576 saved.
# J950 subdata around main shock 576 saved.
# J951 subdata around main shock 576 saved.
# J952 subdata around main shock 576 saved.
# J954 subdata around main shock 576 saved.
# J955 subdata around main shock 576 saved.
# J956 subdata around main shock 576 saved.
# J961 subdata around main shock 576 saved.
# J962 subdata around main shock 576 saved.
# J963 subdata around main shock 576 saved.
# J964 subdata around main shock 576 saved.
# J965 subdata around main shock 576 saved.
# J982 subdata around main shock 576 saved.
# KGNI subdata around main shock 576 saved.
# KSMV subdata around main shock 576 saved.
# MIZT subdata around main shock 576 saved.
# MIZU subdata around main shock 576 saved.
# MTKA subdata around main shock 576 saved.
# MZSW subdata around main shock 576 saved.
# NM0D subdata around main shock 576 saved.
# R007 subdata around main shock 576 saved.
# R008 subdata around main shock 576 saved.
# R009 subdata around main shock 576 saved.
# R010 subdata around main shock 576 saved.
# R012 subdata around main shock 576 saved.
# R013 subdata around main shock 576 saved.
# R014 subdata around main shock 576 saved.
# S054 subdata around main shock 576 saved.
# S055 subdata around main shock 576 saved.
# S056 subdata around main shock 576 saved.
# S057 subdata around main shock 576 saved.
# S058 subdata around main shock 576 saved.
# S059 subdata around main shock 576 saved.
# S063 subdata around main shock 576 saved.
# S064 subdata around main shock 576 saved.
# S065 subdata around main shock 576 saved.
# S066 subdata around main shock 576 saved.
# S067 subdata around main shock 576 saved.
# S069 subdata around main shock 576 saved.
# S070 subdata around main shock 576 saved.
# S110 subdata around main shock 576 saved.
# TKSC subdata around main shock 576 saved.
# TSK2 subdata around main shock 576 saved.
# TSKB subdata around main shock 576 saved.
# X071 subdata around main shock 576 saved.
# Z201 subdata around main shock 576 saved.
# Z212 subdata around main shock 576 saved.
# G103 subdata around main shock 578 saved.
# G145 subdata around main shock 578 saved.
# G150 subdata around main shock 578 saved.
# G159 subdata around main shock 578 saved.
# G173 subdata around main shock 578 saved.
# G174 subdata around main shock 578 saved.
# G175 subdata around main shock 578 saved.
# G177 subdata around main shock 578 saved.
# G184 subdata around main shock 578 saved.
# G191 subdata around main shock 578 saved.
# G196 subdata around main shock 578 saved.
# G199 subdata around main shock 578 saved.
# G203 subdata around main shock 578 saved.
# G204 subdata around main shock 578 saved.
# G205 subdata around main shock 578 saved.
# G219 subdata around main shock 578 saved.
# G220 subdata around main shock 578 saved.
# G221 subdata around main shock 578 saved.
# J007 subdata around main shock 578 saved.
# J009 subdata around main shock 578 saved.
# J010 subdata around main shock 578 saved.
# J011 subdata around main shock 578 saved.
# J012 subdata around main shock 578 saved.
# J013 subdata around main shock 578 saved.
# J014 subdata around main shock 578 saved.
# J015 subdata around main shock 578 saved.
# J016 subdata around main shock 578 saved.
# J018 subdata around main shock 578 saved.
# J019 subdata around main shock 578 saved.
# J021 subdata around main shock 578 saved.
# J022 subdata around main shock 578 saved.
# J023 subdata around main shock 578 saved.
# J024 subdata around main shock 578 saved.
# J026 subdata around main shock 578 saved.
# J027 subdata around main shock 578 saved.
# J028 subdata around main shock 578 saved.
# J030 subdata around main shock 578 saved.
# J112 subdata around main shock 578 saved.
# J117 subdata around main shock 578 saved.
# J121 subdata around main shock 578 saved.
# J122 subdata around main shock 578 saved.
# J124 subdata around main shock 578 saved.
# J125 subdata around main shock 578 saved.
# J128 subdata around main shock 578 saved.
# J130 subdata around main shock 578 saved.
# J132 subdata around main shock 578 saved.
# J133 subdata around main shock 578 saved.
# J134 subdata around main shock 578 saved.
# J135 subdata around main shock 578 saved.
# J136 subdata around main shock 578 saved.
# J137 subdata around main shock 578 saved.
# J138 subdata around main shock 578 saved.
# J139 subdata around main shock 578 saved.
# J140 subdata around main shock 578 saved.
# J141 subdata around main shock 578 saved.
# J142 subdata around main shock 578 saved.
# J143 subdata around main shock 578 saved.
# J144 subdata around main shock 578 saved.
# J145 subdata around main shock 578 saved.
# J146 subdata around main shock 578 saved.
# J147 subdata around main shock 578 saved.
# J150 subdata around main shock 578 saved.
# J151 subdata around main shock 578 saved.
# J152 subdata around main shock 578 saved.
# J153 subdata around main shock 578 saved.
# J154 subdata around main shock 578 saved.
# J155 subdata around main shock 578 saved.
# J156 subdata around main shock 578 saved.
# J157 subdata around main shock 578 saved.
# J158 subdata around main shock 578 saved.
# J159 subdata around main shock 578 saved.
# J160 subdata around main shock 578 saved.
# J161 subdata around main shock 578 saved.
# J162 subdata around main shock 578 saved.
# J163 subdata around main shock 578 saved.
# J164 subdata around main shock 578 saved.
# J165 subdata around main shock 578 saved.
# J166 subdata around main shock 578 saved.
# J167 subdata around main shock 578 saved.
# J170 subdata around main shock 578 saved.
# J171 subdata around main shock 578 saved.
# J172 subdata around main shock 578 saved.
# J173 subdata around main shock 578 saved.
# J175 subdata around main shock 578 saved.
# Data of station J181 around main shock 578 is incomplete or contains NaNs.
# J182 subdata around main shock 578 saved.
# J183 subdata around main shock 578 saved.
# J184 subdata around main shock 578 saved.
# J185 subdata around main shock 578 saved.
# J186 subdata around main shock 578 saved.
# J187 subdata around main shock 578 saved.
# J188 subdata around main shock 578 saved.
# J189 subdata around main shock 578 saved.
# J190 subdata around main shock 578 saved.
# J193 subdata around main shock 578 saved.
# J513 subdata around main shock 578 saved.
# J514 subdata around main shock 578 saved.
# J515 subdata around main shock 578 saved.
# J516 subdata around main shock 578 saved.
# J518 subdata around main shock 578 saved.
# J520 subdata around main shock 578 saved.
# J521 subdata around main shock 578 saved.
# J522 subdata around main shock 578 saved.
# J523 subdata around main shock 578 saved.
# J525 subdata around main shock 578 saved.
# J526 subdata around main shock 578 saved.
# J528 subdata around main shock 578 saved.
# J529 subdata around main shock 578 saved.
# J530 subdata around main shock 578 saved.
# J531 subdata around main shock 578 saved.
# J532 subdata around main shock 578 saved.
# J533 subdata around main shock 578 saved.
# J534 subdata around main shock 578 saved.
# J535 subdata around main shock 578 saved.
# J537 subdata around main shock 578 saved.
# J538 subdata around main shock 578 saved.
# J539 subdata around main shock 578 saved.
# J540 subdata around main shock 578 saved.
# J541 subdata around main shock 578 saved.
# J542 subdata around main shock 578 saved.
# J543 subdata around main shock 578 saved.
# J544 subdata around main shock 578 saved.
# J547 subdata around main shock 578 saved.
# J551 subdata around main shock 578 saved.
# J552 subdata around main shock 578 saved.
# J553 subdata around main shock 578 saved.
# J554 subdata around main shock 578 saved.
# J787 subdata around main shock 578 saved.
# J788 subdata around main shock 578 saved.
# J789 subdata around main shock 578 saved.
# J790 subdata around main shock 578 saved.
# J791 subdata around main shock 578 saved.
# J792 subdata around main shock 578 saved.
# J793 subdata around main shock 578 saved.
# J794 subdata around main shock 578 saved.
# J795 subdata around main shock 578 saved.
# J796 subdata around main shock 578 saved.
# J798 subdata around main shock 578 saved.
# J844 subdata around main shock 578 saved.
# J867 subdata around main shock 578 saved.
# J871 subdata around main shock 578 saved.
# J873 subdata around main shock 578 saved.
# J874 subdata around main shock 578 saved.
# J876 subdata around main shock 578 saved.
# J877 subdata around main shock 578 saved.
# J878 subdata around main shock 578 saved.
# J879 subdata around main shock 578 saved.
# J880 subdata around main shock 578 saved.
# J882 subdata around main shock 578 saved.
# J883 subdata around main shock 578 saved.
# J884 subdata around main shock 578 saved.
# J885 subdata around main shock 578 saved.
# J886 subdata around main shock 578 saved.
# J887 subdata around main shock 578 saved.
# J889 subdata around main shock 578 saved.
# J890 subdata around main shock 578 saved.
# J891 subdata around main shock 578 saved.
# J892 subdata around main shock 578 saved.
# J893 subdata around main shock 578 saved.
# J894 subdata around main shock 578 saved.
# J895 subdata around main shock 578 saved.
# J896 subdata around main shock 578 saved.
# J897 subdata around main shock 578 saved.
# J898 subdata around main shock 578 saved.
# J899 subdata around main shock 578 saved.
# J901 subdata around main shock 578 saved.
# J902 subdata around main shock 578 saved.
# J903 subdata around main shock 578 saved.
# J904 subdata around main shock 578 saved.
# J905 subdata around main shock 578 saved.
# J907 subdata around main shock 578 saved.
# J908 subdata around main shock 578 saved.
# J909 subdata around main shock 578 saved.
# J910 subdata around main shock 578 saved.
# J911 subdata around main shock 578 saved.
# J912 subdata around main shock 578 saved.
# J913 subdata around main shock 578 saved.
# J914 subdata around main shock 578 saved.
# J921 subdata around main shock 578 saved.
# J922 subdata around main shock 578 saved.
# J923 subdata around main shock 578 saved.
# J924 subdata around main shock 578 saved.
# J925 subdata around main shock 578 saved.
# J926 subdata around main shock 578 saved.
# J928 subdata around main shock 578 saved.
# MIZT subdata around main shock 578 saved.
# MIZU subdata around main shock 578 saved.
# MZSW subdata around main shock 578 saved.
# S047 subdata around main shock 578 saved.
# S052 subdata around main shock 578 saved.
# S053 subdata around main shock 578 saved.
# S055 subdata around main shock 578 saved.
# S056 subdata around main shock 578 saved.
# S062 subdata around main shock 578 saved.
# S063 subdata around main shock 578 saved.
# S064 subdata around main shock 578 saved.
# S065 subdata around main shock 578 saved.
# S066 subdata around main shock 578 saved.
# SJ51 subdata around main shock 578 saved.
# STK2 subdata around main shock 578 saved.
# X074 subdata around main shock 578 saved.
# X076 subdata around main shock 578 saved.
# X077 subdata around main shock 578 saved.
# X091 subdata around main shock 578 saved.

# %%
process_and_save_main_shocks_data(mainshocks_gps_stations_daily_positions, mainshocks_days, earthquakes,
                                  min_after_shock_mag,
                                  after_shock_time_window,
                                  n_days_after_mainshock,
                                  hdf5_output_file_path,
                                  min_stations_per_main_shock)
# Out:
# Processing main shock 57...
# Processing main shock 69...
# Processing main shock 89...
# Processing main shock 90...
# Processing main shock 103...
# Processing main shock 104...
# Processing main shock 108...
# Processing main shock 109...
# Processing main shock 114...
# Processing main shock 118...
# Processing main shock 151...
# Processing main shock 153...
# Processing main shock 155...
# Processing main shock 156...
# Processing main shock 158...
# Processing main shock 161...
# Processing main shock 163...
# Processing main shock 172...
# Processing main shock 174...
# Processing main shock 176...
# Processing main shock 177...
# Processing main shock 179...
# Processing main shock 181...
# Processing main shock 182...
# Processing main shock 187...
# Processing main shock 194...
# Processing main shock 198...
# Processing main shock 199...
# Processing main shock 200...
# Processing main shock 203...
# Processing main shock 204...
# Processing main shock 206...
# Processing main shock 207...
# Processing main shock 213...
# Processing main shock 214...
# Processing main shock 215...
# Processing main shock 217...
# Processing main shock 218...
# Processing main shock 219...
# Processing main shock 223...
# Processing main shock 226...
# Processing main shock 228...
# Processing main shock 233...
# Processing main shock 236...
# Processing main shock 248...
# Processing main shock 251...
# Processing main shock 252...
# Processing main shock 256...
# Processing main shock 257...
# Processing main shock 258...
# Processing main shock 265...
# Processing main shock 267...
# Processing main shock 271...
# Processing main shock 275...
# Processing main shock 277...
# Processing main shock 279...
# Processing main shock 280...
# Processing main shock 282...
# Processing main shock 283...
# Processing main shock 284...
# Processing main shock 285...
# Processing main shock 291...
# Processing main shock 293...
# Processing main shock 294...
# Processing main shock 295...
# Processing main shock 296...
# Processing main shock 297...
# Processing main shock 299...
# Processing main shock 300...
# Processing main shock 302...
# Processing main shock 306...
# Processing main shock 308...
# Processing main shock 311...
# Processing main shock 312...
# Processing main shock 314...
# Processing main shock 315...
# Processing main shock 317...
# Processing main shock 318...
# Processing main shock 319...
# Processing main shock 320...
# Processing main shock 321...
# Processing main shock 324...
# Processing main shock 325...
# Processing main shock 335...
# Processing main shock 352...
# Processing main shock 376...
# Processing main shock 378...
# Processing main shock 392...
# Processing main shock 393...
# Processing main shock 410...
# Processing main shock 414...
# Processing main shock 415...
# Processing main shock 418...
# Processing main shock 420...
# Processing main shock 422...
# Processing main shock 424...
# Processing main shock 426...
# Processing main shock 427...
# Processing main shock 429...
# Processing main shock 432...
# Processing main shock 433...
# Processing main shock 435...
# Processing main shock 436...
# Processing main shock 437...
# Processing main shock 438...
# Processing main shock 439...
# Processing main shock 440...
# Processing main shock 442...
# Processing main shock 443...
# Processing main shock 446...
# Processing main shock 447...
# Processing main shock 448...
# Processing main shock 450...
# Processing main shock 451...
# Processing main shock 452...
# Processing main shock 456...
# Processing main shock 457...
# Processing main shock 458...
# Processing main shock 460...
# Processing main shock 461...
# Processing main shock 463...
# Processing main shock 466...
# Processing main shock 467...
# Processing main shock 468...
# Processing main shock 471...
# Processing main shock 473...
# Processing main shock 480...
# Processing main shock 481...
# Processing main shock 484...
# Processing main shock 485...
# Processing main shock 487...
# Processing main shock 489...
# Processing main shock 490...
# Processing main shock 491...
# Processing main shock 492...
# Processing main shock 494...
# Processing main shock 496...
# Processing main shock 504...
# Processing main shock 505...
# Processing main shock 508...
# Processing main shock 510...
# Processing main shock 512...
# Processing main shock 513...
# Processing main shock 514...
# Processing main shock 517...
# Processing main shock 518...
# Processing main shock 525...
# Processing main shock 526...
# Processing main shock 527...
# Processing main shock 531...
# Processing main shock 532...
# Processing main shock 533...
# Processing main shock 534...
# Processing main shock 537...
# Processing main shock 538...
# Processing main shock 539...
# Processing main shock 540...
# Processing main shock 541...
# Processing main shock 543...
# Processing main shock 544...
# Processing main shock 546...
# Processing main shock 551...
# Processing main shock 552...
# Processing main shock 553...
# Processing main shock 554...
# Processing main shock 556...
# Processing main shock 557...
# Processing main shock 562...
# Processing main shock 563...
# Processing main shock 565...
# Processing main shock 566...
# Processing main shock 567...
# Processing main shock 568...
# Processing main shock 570...
# Processing main shock 572...
# Processing main shock 573...
# Processing main shock 575...
# Processing main shock 576...
# Processing main shock 578...

# %%
#converted_first2[11]

# %%
#haversined2[11]
